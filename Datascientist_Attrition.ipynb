# %% [markdown]
# <a href="https://colab.research.google.com/github/FreddyR424/Deep_Learning/blob/master/Datascientist_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Scientist Attrition - Job Change Among Data Scientists**

# %% [markdown]
# ## **Problem Statement**
# - A company that is active in Big Data and Data Science wants to hire data scientists among people who successfully pass some courses conducted by the company. Many people sign up for their training. The company wants to know which of these candidates want to work for the company after training or looking for new employment because it helps to reduce the cost and time as well as the quality of training or planning the courses and categorization of candidates. Information related to demographics, education and experience is provided by candidates during signup and enrollment.
# - This dataset is designed to understand the factors that lead a person to leave their current job, and it is hence useful for HR research. By building a model that uses the current credentials, demographics, and work experience related data, you will predict the probability that a candidate is looking for a new job, as well as interpret the main factors that affect an employee's decision whether to continue or attrite.

# %% [markdown]
# ## **Dataset Description**
# - **Enrollee_id:** Unique ID for candidate
# - **City:** City code
# - **City_development_index:** Developement index of the city (scaled)
# - **Gender:** Gender of candidate
# - **Relevent_experience:** Relevant experience of candidate
# - **Enrolled_university:** Type of University course enrolled if any
# - **Education_level:** Education level of candidate
# - **Major_discipline:** Education major discipline of candidate
# - **Experience:** Candidate total experience in years
# - **Company_size:** No of employees in current employer's company
# - **Company_type:** Type of current employer
# - **Last_new_job:** Difference in years between previous job and current job
# - **Training_hours:** training hours completed
# - **Target:** 0 – Not looking for job change, 1 – Looking for a job change

# %% [markdown]
# ## **Imports**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import model_selection
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import warnings
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import random
from tensorflow.keras import backend
random.seed(1)
np.random.seed(1) 
tf.random.set_seed(1)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Loading the Data**

# %%
data = pd.read_csv('Data (1).csv')

# %%
data.shape
# Out:
# (19158, 14)

# %% [markdown]
# - The dataset has 19158 rows and 14 columns

# %% [markdown]
# ## **Data Overview**

# %%
data.head()
# Out:
#    Enrollee_id      City  City_development_index Gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        Relevent_experience Enrolled_university Education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   Major_discipline Experience Company_size    Company_type Last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    Training_hours  Target
# 0              36       1
# 1              47       0
# 2              83       0
# 3              52       1
# 4               8       0

# %%
data.tail()
# Out:
#        Enrollee_id      City  City_development_index Gender  \
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            Relevent_experience Enrolled_university Education_level  \
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       Major_discipline Experience Company_size Company_type Last_new_job  \
# 19153       Humanities         14          NaN          NaN            1
# 19154             STEM         14          NaN          NaN            4
# 19155             STEM        >20        50-99      Pvt Ltd            4
# 19156              NaN         <1      500-999      Pvt Ltd            2
# 19157              NaN          2          NaN          NaN            1
#
#        Training_hours  Target
# 19153              42       1
# 19154              52       1
# 19155              44       0
# 19156              97       0
# 19157             127       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Enrollee_id             19158 non-null  int64
#  1   City                    19158 non-null  object
#  2   City_development_index  19158 non-null  float64
#  3   Gender                  14650 non-null  object
#  4   Relevent_experience     19158 non-null  object
#  5   Enrolled_university     18772 non-null  object
#  6   Education_level         18698 non-null  object
#  7   Major_discipline        16345 non-null  object
#  8   Experience              19093 non-null  object
#  9   Company_size            13220 non-null  object
#  10  Company_type            13018 non-null  object
#  11  Last_new_job            18735 non-null  object
#  12  Training_hours          19158 non-null  int64
#  13  Target                  19158 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.0+ MB

# %% [markdown]
# - There are 19,158 observations and 14 columns in the data.
# - 10 columns are of the object datatype and 4 columns are numerical.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values
round(data.isnull().sum() / data.isnull().count() * 100, 2)
# Out:
# Enrollee_id                0.00
# City                       0.00
# City_development_index     0.00
# Gender                    23.53
# Relevent_experience        0.00
# Enrolled_university        2.01
# Education_level            2.40
# Major_discipline          14.68
# Experience                 0.34
# Company_size              30.99
# Company_type              32.05
# Last_new_job               2.21
# Training_hours             0.00
# Target                     0.00
# dtype: float64

# %%
data["Target"].value_counts(1)
# Out:
# 0    0.750652
# 1    0.249348
# Name: Target, dtype: float64

# %%
# Statistical summary
data.describe().T
# Out:
#                           count          mean          std    min      25%  \
# Enrollee_id             19158.0  16875.358179  9616.292592  1.000  8554.25
# City_development_index  19158.0      0.828848     0.123362  0.448     0.74
# Training_hours          19158.0     65.366896    60.058462  1.000    23.00
# Target                  19158.0      0.249348     0.432647  0.000     0.00
#
#                               50%       75%        max
# Enrollee_id             16982.500  25169.75  33380.000
# City_development_index      0.903      0.92      0.949
# Training_hours             47.000     88.00    336.000
# Target                      0.000      0.00      1.000

# %% [markdown]
# - Outside of the Enrollee_id (an ID column) and the Target variable, there are only two numerical columns in the dataset.
#
# - The maximum number of training hours is 336, but at least 75% of employees had finished their training within 88 hours.
# - 50% of the rows have a city development index between 0.903 and 0.949, so the dataset is weighted towards the higher side with respect to this column.

# %%
data.nunique()
# Out:
# Enrollee_id               19158
# City                        123
# City_development_index       93
# Gender                        3
# Relevent_experience           2
# Enrolled_university           3
# Education_level               5
# Major_discipline              6
# Experience                   22
# Company_size                  8
# Company_type                  6
# Last_new_job                  6
# Training_hours              241
# Target                        2
# dtype: int64

# %% [markdown]
# - Each value of the column 'Employee_id' is a unique identifier for an employee. Hence we can drop this column as it will not add any predictive power or value to the model.
# - The 'City' column has 123 unique categories.

# %%
for i in data.describe(include = ["object"]).columns:
  print("Unique values in", i, "are :")
  print(data[i].value_counts())
  print("*" * 50)
# Out:
# Unique values in City are :
# city_103    4355
# city_21     2702
# city_16     1533
# city_114    1336
# city_160     845
#             ...
# city_129       3
# city_111       3
# city_121       3
# city_140       1
# city_171       1
# Name: City, Length: 123, dtype: int64
# **************************************************
# Unique values in Gender are :
# Male      13221
# Female     1238
# Other       191
# Name: Gender, dtype: int64
# **************************************************
# Unique values in Relevent_experience are :
# Has relevent experience    13792
# No relevent experience      5366
# Name: Relevent_experience, dtype: int64
# **************************************************
# Unique values in Enrolled_university are :
# no_enrollment       13817
# Full time course     3757
# Part time course     1198
# Name: Enrolled_university, dtype: int64
# **************************************************
# Unique values in Education_level are :
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: Education_level, dtype: int64
# **************************************************
# Unique values in Major_discipline are :
# STEM               14492
# Humanities           669
# Other                381
# Business Degree      327
# Arts                 253
# No Major             223
# Name: Major_discipline, dtype: int64
# **************************************************
# Unique values in Experience are :
# >20    3286
# 5      1430
# 4      1403
# 3      1354
# 6      1216
# 2      1127
# 7      1028
# 10      985
# 9       980
# 8       802
# 15      686
# 11      664
# 14      586
# 1       549
# <1      522
# 16      508
# 12      494
# 13      399
# 17      342
# 19      304
# 18      280
# 20      148
# Name: Experience, dtype: int64
# **************************************************
# Unique values in Company_size are :
# 50-99        3083
# 100-500      2571
# 10000+       2019
# Oct-49       1471
# 1000-4999    1328
# <10          1308
# 500-999       877
# 5000-9999     563
# Name: Company_size, dtype: int64
# **************************************************
# Unique values in Company_type are :
# Pvt Ltd                9817
# Funded Startup         1001
# Public Sector           955
# Early Stage Startup     603
# NGO                     521
# Other                   121
# Name: Company_type, dtype: int64
# **************************************************
# Unique values in Last_new_job are :
# 1        8040
# >4       3290
# 2        2900
# never    2452
# 4        1029
# 3        1024
# Name: Last_new_job, dtype: int64
# **************************************************

# %% [markdown]
# - The 'City' column has 123 unique categories, and the city with the highest number of employees is City 103.
# - Over 90% of the employees in this dataset are males, so it is highly gender-skewed.
# - Most of the employees (~70%) have relevant experience in Data Science.
# - 70% of the employees did not enroll in any of the courses.
# - Most of the employees have a Bachelor's level of education (Graduation) but not more than that (~62% of the total number of employees). There are very few employees with Master's degrees and PhDs.
# - Almost all the employees have previous experience (Related and Non-Related).
# - ~75% of the employees are from private companies.

# %% [markdown]
# ## **Data Pre-processing**

# %%
data.drop(columns = "Enrollee_id", inplace = True)

# %% [markdown]
# ## **EDA**

# %% [markdown]
# ### **Univariate Analysis**

# %%
# Function to plot a boxplot and a histogram along the same scale.

def histogram_boxplot(data, feature, figsize = (12, 7), kde = False, bins = None):
  """
  Boxplot and Histogram combined

  data: dataframe
  feature: dataframe column
  figsize: size of figure (default (12, 7))
  kde: whether to the show density curve (default False)
  bins: number of bins for histogram (default None)
  """
  f2, (ax_box2, ax_hist2) = plt.subplots(
      nrows = 2, 
      sharex = True,
      gridspec_kw = {"height_ratios": (0.25, 0.75)},
      figsize = figsize,
  )
  sns.boxplot(
      data= data, x= feature, ax= ax_box2, showmeans= True, color= "violet"
  )
  sns.histplot(
      data= data, x= feature, kde= kde, ax= ax_hist2, bins= bins, palette= "winter"
  ) if bins else sns.histplot(
      data= data, x= feature, kde= kde, ax= ax_hist2
  )
  ax_hist2.axvline(
      data[feature].mean(), color= "green", linestyle= "--"
  )
  ax_hist2.axvline(
      data[feature].median(), color= "black", linestyle= "-"
  )

# %%
data.dtypes
# Out:
# City                       object
# City_development_index    float64
# Gender                     object
# Relevent_experience        object
# Enrolled_university        object
# Education_level            object
# Major_discipline           object
# Experience                 object
# Company_size               object
# Company_type               object
# Last_new_job               object
# Training_hours              int64
# Target                      int64
# dtype: object

# %%
histogram_boxplot(data, "City_development_index")

# %% [markdown]
# - there are many people from cities having a development index more than 0.9.

# %%
histogram_boxplot(data, "Training_hours")

# %% [markdown]
# -  the measures of central tendency with respect to training hours seem to be 70, despite a maximum value over 300 hours. So most of the people in this dataset have undergone traning for less than 100 hours.

# %%
# Function to create labeled barplots

def labeled_barplot(data, feature, perc= False, n= None):
  """

  Barplot with percentage at top

  data: dataframe
  feature: dataframe column
  perc: whether to display percentages instead of count (default is False)
  n: displays the top n category levels (default is None, i.e., display all levels)
  """

  total = len(data[feature])
  count = data[feature].nunique()
  if n is None:
    plt.figure(figsize= (count + 1, 5))
  else:
    plt.figure(figsize= (n + 1, 5))

  plt.xticks(rotation = 90, fontsize = 15)
  ax = sns.countplot(
      data= data,
      x= feature,
      palette= "Paired",
      order = data[feature].value_counts().index[:n].sort_values(),
  )

  for p in ax.patches:
    if perc == True:
      label= "{:.1f}%".format(
          100 * p.get_height() / total
      )
    else:
      label= p.get_height()

    x= p.get_x() + p.get_width() / 2
    y= p.get_height()

    ax.annotate(
        label, 
        (x, y),
        ha= "center",
        va= "center",
        size= 12,
        xytext= (0, 5),
        textcoords= "offset points",
    )

  plt.show()

# %%
labeled_barplot(data, "Gender")

# %% [markdown]
# - There are far more males in this dataset in comparison to females.
# - Over 90% of this dataset is male, representing a highly gender-skewed dataset. This could be a limitation with respect to implementing this model in the real world, since gender balance is highly important to create machine learning models that are practically implemented on datasets related to people.

# %%
labeled_barplot(data, "Relevent_experience")

# %% [markdown]
# - Most of the employees have relevant prior experience (~70%).
# - 30% of the employees, however, have no relevant experience.

# %%
labeled_barplot(data, "Enrolled_university")

# %% [markdown]
# - Most of the employees did not enroll in any of the courses.
# - Approximately 20% of the employees have enrolled themselves in full-time courses.
# - Only 6% have enrolled in part-time courses.

# %%
labeled_barplot(data, "Education_level")

# %% [markdown]
# - Approximately 62% of employees have a Bachelor's (Graduate) level of education, but not more than that.
# - Approx 23% of employees have a Master's degree as their highest level of education.
# - There are very few employees (~1.5%) with only a High School level of education or below.

# %%
labeled_barplot(data, "Major_discipline")

# %% [markdown]
# - Approximately 88% of employees have opted for STEM as their major discipline.

# %%
labeled_barplot(data, "Company_type")

# %% [markdown]
# - Approximately 75% of the total employees are from a private limited company, showing the skew of the profile towards the private sector.

# %%
print(data.Target.value_counts())
labels = 'Looking for job change', 'Not looking for job change'

sizes = [data.Target[data['Target']== 1].count(), data.Target[data['Target']== 0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize= (10, 8))
ax1.pie(sizes, explode= explode, labels= labels, autopct= '%1.1f%%',
        shadow= True, startangle= 90)
ax1.axis('equal')
plt.title("Proportion", size= 20)
plt.show()
# Out:
# 0    14381
# 1     4777
# Name: Target, dtype: int64

# %% [markdown]
# - This pie chart shows that the actual distribution of classes is itself imbalanced for the target variable.
# - Only ~25% of the employees in this dataset are actually looking for a job change.

# %% [markdown]
# ### **Bivariate Analysis**

# %%
# Function to plot distributions

def distribution_plot_wrt_target(data, predictor, target):
  fig, axs = plt.subplots(2, 2, figsize= (12, 10))
  target_uniq = data[target].unique()
  axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[1]))
  sns.histplot(
      data= data[data[target] == target_uniq[0]],
      x= predictor,
      kde= True,
      ax= axs[0, 0],
      color= "teal",
  )
  
  axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
  sns.histplot(
      data= data[data[target] == target_uniq[1]],
      x= predictor,
      kde= True,
      ax= axs[0, 1],
      color= "orange",
  )

  axs[1, 0].set_title("Boxplot w.r.t target")
  sns.boxplot(data= data, x= target, y= predictor, ax= axs[1, 0], palette= "gist_rainbow")

  axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
  sns.boxplot(
      data= data,
      x= target,
      y= predictor,
      ax= axs[1, 1],
      showfliers= False,
      palette = "gist_rainbow",
  )

  plt.tight_layout()
  plt.show()

# %%
distribution_plot_wrt_target(data, "City_development_index", "Target")

# %% [markdown]
# - From the above plot, we observe that employees from cities having a development index over 0.9, are not willing to switch their jobs.

# %%
distribution_plot_wrt_target(data, "Training_hours", "Target")

# %% [markdown]
# - We observe that the distribution of the training hours with respect to the target variable is rightly skewed, and from the box plot for both classes the median traning hours are around 50.

# %%
# function to plot stacked bar chart

def stacked_barplot(data, predictor, target):
  """
  Print the category counts and plot a stacked bar chart

  data: dataframe
  predictor: independent variable
  target: target variable
  """

  count = data[predictor].nunique()
  sorter = data[target].value_counts().index[-1]
  tab1 = pd.crosstab(data[predictor], data[target], margins = True).sort_values(
      by= sorter, ascending = False
  )
  print(tab1)
  print("-" * 120)
  tab = pd.crosstab(data[predictor], data[target], normalize= "index").sort_values(
      by = sorter, ascending = False
  )
  tab.plot(kind= "bar", stacked= True, figsize= (count + 1, 5))
  plt.legend(
      loc = "lower left",
      frameon = False,
  )
  plt.legend(loc= "upper left", bbox_to_anchor= (1, 1))
  plt.show()

# %%
stacked_barplot(data, "Gender", "Target")
# Out:
# Target      0     1    All
# Gender
# All     11262  3388  14650
# Male    10209  3012  13221
# Female    912   326   1238
# Other     141    50    191
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - the likelihood of the employee choosing a job switch does not depend on their gender.

# %%
stacked_barplot(data, "Relevent_experience", "Target")
# Out:
# Target                       0     1    All
# Relevent_experience
# All                      14381  4777  19158
# Has relevent experience  10831  2961  13792
# No relevent experience    3550  1816   5366
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - employees from Non-relevant experience are more likely to be switching their job.

# %%
stacked_barplot(data, "Enrolled_university", "Target")
# Out:
# Target                   0     1    All
# Enrolled_university
# All                  14118  4654  18772
# no_enrollment        10896  2921  13817
# Full time course      2326  1431   3757
# Part time course       896   302   1198
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Employees who have taken full-time courses in universities are the ones who are more likely to be trying to switch jobs.

# %%
stacked_barplot(data, "Education_level", "Target")
# Out:
# Target               0     1    All
# Education_level
# All              14025  4673  18698
# Graduate          8353  3245  11598
# Masters           3426   935   4361
# High School       1623   394   2017
# Phd                356    58    414
# Primary School     267    41    308
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Employees who completed Graduation and Master's degrees are more likely to be trying to switch their jobs.

# %%
stacked_barplot(data, "Major_discipline", "Target")
# Out:
# Target                0     1    All
# Major_discipline
# All               12117  4228  16345
# STEM              10701  3791  14492
# Humanities          528   141    669
# Other               279   102    381
# Business Degree     241    86    327
# No Major            168    55    223
# Arts                200    53    253
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Employees who took STEM or Business Degrees as their major discipline are slightly more likely to change their job.

# %%
stacked_barplot(data, "Experience", "Target")
# Out:
# Target          0     1    All
# Experience
# All         14339  4754  19093
# >20          2783   503   3286
# 3             876   478   1354
# 4             946   457   1403
# 5            1018   412   1430
# 2             753   374   1127
# 6             873   343   1216
# 7             725   303   1028
# <1            285   237    522
# 1             316   233    549
# 9             767   213    980
# 10            778   207    985
# 8             607   195    802
# 11            513   151    664
# 15            572   114    686
# 14            479   107    586
# 12            402    92    494
# 13            322    77    399
# 16            436    72    508
# 17            285    57    342
# 19            251    53    304
# 18            237    43    280
# 20            115    33    148
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - employees having a work experience of less than 3 years are trying to switch their jobs.

# %%
stacked_barplot(data, "Last_new_job", "Target")
# Out:
# Target            0     1    All
# Last_new_job
# All           14112  4623  18735
# 1              5915  2125   8040
# never          1713   739   2452
# 2              2200   700   2900
# >4             2690   600   3290
# 3               793   231   1024
# 4               801   228   1029
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Employees who have never switched their job before are the most likely to be looking for a job change.

# %%
# Dropping these columns as they will not add value to the modeling

data.drop(['Company_size', 'Gender', 'City'], axis= 1, inplace= True)

# %%
# Separating all the categorical columns for imputation

cat_col_df = data.drop(['City_development_index', 'Training_hours', 'Target'], axis = 1)

# %% [markdown]
# ## **Missing Value Imputation**

# %%
# Separating Independent and Dependent Columns

X = data.drop(['Target'], axis = 1)
Y = data[['Target']]

# %%
Y.head()
# Out:
#    Target
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0

# %%
# Splitting the dataset into the Training and Testing set.

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42, stratify = Y)

# %%
X_train.isnull().sum()
# Out:
# City_development_index       0
# Relevent_experience          0
# Enrolled_university        317
# Education_level            362
# Major_discipline          2258
# Experience                  50
# Company_type              4881
# Last_new_job               343
# Training_hours               0
# dtype: int64

# %%
imputer_mode = SimpleImputer(strategy = "most_frequent")
X_train[["Enrolled_university", "Education_level", "Major_discipline", "Experience", "Company_type", "Last_new_job"]] = imputer_mode.fit_transform(
    X_train[["Enrolled_university", "Education_level", "Major_discipline", "Experience", "Company_type", "Last_new_job"]])

X_test[["Enrolled_university","Education_level","Major_discipline","Experience","Company_type","Last_new_job"]] = imputer_mode.transform(
    X_test[["Enrolled_university","Education_level","Major_discipline","Experience","Company_type","Last_new_job"]])

# %%
# Checking that no column has missing values in train and test sets

print(X_train.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# City_development_index    0
# Relevent_experience       0
# Enrolled_university       0
# Education_level           0
# Major_discipline          0
# Experience                0
# Company_type              0
# Last_new_job              0
# Training_hours            0
# dtype: int64
# ------------------------------
# City_development_index    0
# Relevent_experience       0
# Enrolled_university       0
# Education_level           0
# Major_discipline          0
# Experience                0
# Company_type              0
# Last_new_job              0
# Training_hours            0
# dtype: int64

# %% [markdown]
# ### **Encoding Categorical Columns**
# - using the Label Encoding technique to encode the values of the categorical columns in this dataset.

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder_RE = LabelEncoder()
X_train['Relevent_experience']= labelencoder_RE.fit_transform(X_train['Relevent_experience'])
X_test['Relevent_experience']= labelencoder_RE.transform(X_test['Relevent_experience'])

# %%
labelencoder_EN = LabelEncoder()
X_train['Enrolled_university']= labelencoder_RE.fit_transform(X_train['Enrolled_university'])
X_test['Enrolled_university']= labelencoder_RE.transform(X_test['Enrolled_university'])

# %%
labelencoder_EL = LabelEncoder()
X_train['Education_level']=  labelencoder_EL.fit_transform(X_train['Education_level'])
X_test['Education_level']=  labelencoder_EL.transform(X_test['Education_level'])

# %%
labelencoder_MD = LabelEncoder()
X_train['Major_discipline']=  labelencoder_MD.fit_transform(X_train['Major_discipline'])
X_test['Major_discipline']=  labelencoder_MD.transform(X_test['Major_discipline'])

# %%
labelencoder_EX = LabelEncoder()
X_train['Experience']=  labelencoder_EX.fit_transform(X_train['Experience'])
X_test['Experience']=  labelencoder_EX.transform(X_test['Experience'])

# %%
labelencoder_CT = LabelEncoder()
X_train['Company_type']=  labelencoder_CT.fit_transform(X_train['Company_type'])
X_test['Company_type']=  labelencoder_CT.transform(X_test['Company_type'])

# %%
labelencoder_LNJ = LabelEncoder()
X_train['Last_new_job']=  labelencoder_LNJ.fit_transform(X_train['Last_new_job'])
X_test['Last_new_job']=  labelencoder_LNJ.transform(X_test['Last_new_job'])

# %%
X_train.head()
# Out:
#        City_development_index  Relevent_experience  Enrolled_university  \
# 17855                   0.624                    0                    2
# 17664                   0.920                    1                    2
# 13404                   0.896                    0                    2
# 13366                   0.920                    0                    2
# 15670                   0.855                    0                    0
#
#        Education_level  Major_discipline  Experience  Company_type  \
# 17855                0                 5           1             5
# 17664                4                 5          15             5
# 13404                0                 5           3             2
# 13366                0                 5          15             1
# 15670                0                 5          15             5
#
#        Last_new_job  Training_hours
# 17855             0              90
# 17664             5              15
# 13404             4              36
# 13366             0              53
# 15670             0             158

# %%
y_train.head()
# Out:
#        Target
# 17855       0
# 17664       0
# 13404       0
# 13366       0
# 15670       1

# %%
# Checking the shape of train and test sets

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15326, 9)
# (3832, 9)
# (15326, 1)
# (3832, 1)

# %% [markdown]
# ## **Model Building**
#
# **Possible Wrong Predictions:**
# - Predicting an employee is looking for a job, when he/she is not looking for it.
# - Predicting an employee is not looking for a job, when he/she is in fact looking for one.
#
# **Case Importance**
# - Both cases are actually important for the purposes of this case study. Not giving a chance to a deserving employee (by wrongly classifying them as likely to attrite) might lead to decreased productivity, and the company might lose a good employee affecting the organization's growth. However, giving chances to a non-deserving employee (as they are likely to attrite) would lead to a financial loss for the company, and giving such employees an increased amount of responsibility might again affect the company's growth.
#
# **How to reduce this loss i.e need to reduce False Negatives as well as False Positives?**
# - Since both errors are important for us to minimize, the company would want the F1 Score evaluation metric to be maximized/ Hence, the focus should be on increasing the F1 score rather than focusing on just one metric i.e. Recall or Precision.

# %% [markdown]
# ## **Model 1**

# %%
backend.clear_session()

np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the ANN
model = Sequential()

model.add(Dense(activation = 'relu', input_dim = 9, units = 64))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
# Create optimizer with default learning rate
# Compile the model

model.compile(optimizer = 'SGD', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,753
# Trainable params: 2,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                    validation_split = 0.2,
                    epochs = 50,
                    batch_size = 32, verbose = 1)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 4ms/step - loss: 0.6834 - accuracy: 0.7433 - val_loss: 0.6449 - val_accuracy: 0.7515
# Epoch 2/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5688 - accuracy: 0.7503 - val_loss: 0.5592 - val_accuracy: 0.7515
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5615 - accuracy: 0.7504 - val_loss: 0.5545 - val_accuracy: 0.7515
# Epoch 4/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5611 - accuracy: 0.7504 - val_loss: 0.5567 - val_accuracy: 0.7515
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5597 - accuracy: 0.7504 - val_loss: 0.5725 - val_accuracy: 0.7515
# Epoch 6/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5590 - accuracy: 0.7504 - val_loss: 0.5968 - val_accuracy: 0.7515
# Epoch 7/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7504 - val_loss: 0.5693 - val_accuracy: 0.7515
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7504 - val_loss: 0.5571 - val_accuracy: 0.7515
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7504 - val_loss: 0.5608 - val_accuracy: 0.7515
# Epoch 10/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7504 - val_loss: 0.5484 - val_accuracy: 0.7515
# Epoch 11/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7504 - val_loss: 0.5634 - val_accuracy: 0.7511
# Epoch 12/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5530 - accuracy: 0.7504 - val_loss: 0.5697 - val_accuracy: 0.7515
# Epoch 13/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7504 - val_loss: 0.5755 - val_accuracy: 0.7515
# Epoch 14/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5533 - accuracy: 0.7504 - val_loss: 0.5487 - val_accuracy: 0.7518
# Epoch 15/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7504 - val_loss: 0.5541 - val_accuracy: 0.7515
# Epoch 16/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7503 - val_loss: 0.5648 - val_accuracy: 0.7505
# Epoch 17/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7504 - val_loss: 0.5579 - val_accuracy: 0.7515
# Epoch 18/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7502 - val_loss: 0.5445 - val_accuracy: 0.7515
# Epoch 19/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5501 - accuracy: 0.7503 - val_loss: 0.5491 - val_accuracy: 0.7518
# Epoch 20/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7511 - val_loss: 0.5461 - val_accuracy: 0.7515
# Epoch 21/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5490 - accuracy: 0.7506 - val_loss: 0.5479 - val_accuracy: 0.7515
# Epoch 22/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7503 - val_loss: 0.5444 - val_accuracy: 0.7515
# Epoch 23/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.5491 - accuracy: 0.7504 - val_loss: 0.5858 - val_accuracy: 0.7534
# Epoch 24/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.5484 - accuracy: 0.7504 - val_loss: 0.5447 - val_accuracy: 0.7521
# Epoch 25/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5495 - accuracy: 0.7505 - val_loss: 0.5453 - val_accuracy: 0.7515
# Epoch 26/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7503 - val_loss: 0.5789 - val_accuracy: 0.7515
# Epoch 27/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7503 - val_loss: 0.5494 - val_accuracy: 0.7524
# Epoch 28/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7505 - val_loss: 0.5422 - val_accuracy: 0.7515
# Epoch 29/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5489 - accuracy: 0.7509 - val_loss: 0.5565 - val_accuracy: 0.7521
# Epoch 30/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5480 - accuracy: 0.7507 - val_loss: 0.5423 - val_accuracy: 0.7518
# Epoch 31/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5475 - accuracy: 0.7505 - val_loss: 0.5423 - val_accuracy: 0.7531
# Epoch 32/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7499 - val_loss: 0.5477 - val_accuracy: 0.7515
# Epoch 33/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7506 - val_loss: 0.5751 - val_accuracy: 0.7538
# Epoch 34/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5476 - accuracy: 0.7507 - val_loss: 0.5559 - val_accuracy: 0.7531
# Epoch 35/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7510 - val_loss: 0.5451 - val_accuracy: 0.7515
# Epoch 36/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5461 - accuracy: 0.7504 - val_loss: 0.5491 - val_accuracy: 0.7515
# Epoch 37/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7511 - val_loss: 0.5641 - val_accuracy: 0.7567
# Epoch 38/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7511 - val_loss: 0.5421 - val_accuracy: 0.7515
# Epoch 39/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7506 - val_loss: 0.5466 - val_accuracy: 0.7515
# Epoch 40/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7511 - val_loss: 0.5392 - val_accuracy: 0.7538
# Epoch 41/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7499 - val_loss: 0.5485 - val_accuracy: 0.7521
# Epoch 42/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7511 - val_loss: 0.5569 - val_accuracy: 0.7521
# Epoch 43/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7508 - val_loss: 0.5623 - val_accuracy: 0.7515
# Epoch 44/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7511 - val_loss: 0.5422 - val_accuracy: 0.7515
# Epoch 45/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7509 - val_loss: 0.5407 - val_accuracy: 0.7524
# Epoch 46/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7507 - val_loss: 0.5427 - val_accuracy: 0.7528
# Epoch 47/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5444 - accuracy: 0.7511 - val_loss: 0.5640 - val_accuracy: 0.7531
# Epoch 48/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7506 - val_loss: 0.5375 - val_accuracy: 0.7521
# Epoch 49/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5444 - accuracy: 0.7516 - val_loss: 0.5388 - val_accuracy: 0.7521
# Epoch 50/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7507 - val_loss: 0.5392 - val_accuracy: 0.7521

# %%
# Capturing learning history per epoch
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Plotting accuracy at different epochs
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train", "valid"), loc = 0)

results = model.evaluate(X_test, y_test)
# Out:
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5391 - accuracy: 0.7505

# %% [markdown]
# - There is noise in the loss behavior here. Sometimes, the loss function fluctuates a lot during training, which makes the convergence slow. These fluctuations are due to the nature of Stochastic Gradient Descent that produces noisy updates in the parameters.

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    '''

    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])

    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False

    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    
    if title:
        plt.title(title)

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %% [markdown]
# - Here, the 0.03% of False Negatives is because we gave 0.5 as the threshold to the model, and as this is an imbalanced dataset, we should calculate the threshold using the AUC-ROC curve.

# %%
#Accuracy as per the classification report
 
from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86      2877
#            1       0.00      0.00      0.00       955
#
#     accuracy                           0.75      3832
#    macro avg       0.38      0.50      0.43      3832
# weighted avg       0.56      0.75      0.64      3832

# %% [markdown]
# - the above model has a good accuracy but a poor F1-score. This could be due to the imbalanced dataset. We observe that the False positive rates are also high, which should be considerably lower.
#
# - 1) Imbalanced dataset: As you have seen in the EDA, this dataset is imbalanced, and it contains more examples that belong to the 0 class.
#
# - 2) Decision Threshold: Due to the imbalanced dataset, we can use ROC-AUC to find the optimal threshold and use the same for prediction.

# %% [markdown]
# ## **Model 2**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model1 = Sequential()
     
#Adding the hidden and output layers
model1.add(Dense(256,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model1.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
model1.add(Dense(1, activation = 'sigmoid'))
      
#Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2560
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 3s 10ms/step - loss: 1.2937 - accuracy: 0.6873 - val_loss: 0.6376 - val_accuracy: 0.6341
# Epoch 2/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7310 - accuracy: 0.7076 - val_loss: 0.6492 - val_accuracy: 0.6504
# Epoch 3/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6366 - accuracy: 0.7224 - val_loss: 0.6214 - val_accuracy: 0.7515
# Epoch 4/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6091 - accuracy: 0.7272 - val_loss: 0.5586 - val_accuracy: 0.7462
# Epoch 5/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5900 - accuracy: 0.7334 - val_loss: 0.6115 - val_accuracy: 0.7518
# Epoch 6/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5714 - accuracy: 0.7409 - val_loss: 0.5545 - val_accuracy: 0.7495
# Epoch 7/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5773 - accuracy: 0.7375 - val_loss: 0.5369 - val_accuracy: 0.7521
# Epoch 8/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5503 - accuracy: 0.7462 - val_loss: 0.6073 - val_accuracy: 0.6840
# Epoch 9/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5547 - accuracy: 0.7436 - val_loss: 0.5604 - val_accuracy: 0.7423
# Epoch 10/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5551 - accuracy: 0.7459 - val_loss: 0.5389 - val_accuracy: 0.7502
# Epoch 11/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5557 - accuracy: 0.7491 - val_loss: 0.5981 - val_accuracy: 0.6980
# Epoch 12/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5486 - accuracy: 0.7471 - val_loss: 0.5678 - val_accuracy: 0.7466
# Epoch 13/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5479 - accuracy: 0.7510 - val_loss: 0.5353 - val_accuracy: 0.7498
# Epoch 14/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5457 - accuracy: 0.7476 - val_loss: 0.5512 - val_accuracy: 0.7466
# Epoch 15/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5399 - accuracy: 0.7497 - val_loss: 0.5442 - val_accuracy: 0.7508
# Epoch 16/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5421 - accuracy: 0.7482 - val_loss: 0.5655 - val_accuracy: 0.7479
# Epoch 17/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5357 - accuracy: 0.7514 - val_loss: 0.5316 - val_accuracy: 0.7511
# Epoch 18/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5409 - accuracy: 0.7480 - val_loss: 0.5295 - val_accuracy: 0.7515
# Epoch 19/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5403 - accuracy: 0.7479 - val_loss: 0.5314 - val_accuracy: 0.7538
# Epoch 20/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5441 - accuracy: 0.7501 - val_loss: 0.5299 - val_accuracy: 0.7498
# Epoch 21/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5386 - accuracy: 0.7508 - val_loss: 0.5238 - val_accuracy: 0.7544
# Epoch 22/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5364 - accuracy: 0.7511 - val_loss: 0.5556 - val_accuracy: 0.7515
# Epoch 23/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5423 - accuracy: 0.7493 - val_loss: 0.5504 - val_accuracy: 0.7521
# Epoch 24/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5340 - accuracy: 0.7518 - val_loss: 0.5301 - val_accuracy: 0.7518
# Epoch 25/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5293 - accuracy: 0.7528 - val_loss: 0.5286 - val_accuracy: 0.7502
# Epoch 26/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5295 - accuracy: 0.7517 - val_loss: 0.5293 - val_accuracy: 0.7531
# Epoch 27/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5380 - accuracy: 0.7511 - val_loss: 0.5444 - val_accuracy: 0.7538
# Epoch 28/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5305 - accuracy: 0.7505 - val_loss: 0.5207 - val_accuracy: 0.7502
# Epoch 29/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5277 - accuracy: 0.7555 - val_loss: 0.5195 - val_accuracy: 0.7528
# Epoch 30/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5405 - accuracy: 0.7487 - val_loss: 0.5312 - val_accuracy: 0.7524
# Epoch 31/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5245 - accuracy: 0.7555 - val_loss: 0.5208 - val_accuracy: 0.7518
# Epoch 32/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5243 - accuracy: 0.7544 - val_loss: 0.5258 - val_accuracy: 0.7515
# Epoch 33/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5215 - accuracy: 0.7547 - val_loss: 0.5173 - val_accuracy: 0.7551
# Epoch 34/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5289 - accuracy: 0.7558 - val_loss: 0.5314 - val_accuracy: 0.7492
# Epoch 35/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5185 - accuracy: 0.7551 - val_loss: 0.5670 - val_accuracy: 0.7505
# Epoch 36/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5204 - accuracy: 0.7569 - val_loss: 0.5192 - val_accuracy: 0.7502
# Epoch 37/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5290 - accuracy: 0.7514 - val_loss: 0.5516 - val_accuracy: 0.7498
# Epoch 38/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5212 - accuracy: 0.7551 - val_loss: 0.5301 - val_accuracy: 0.7508
# Epoch 39/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5232 - accuracy: 0.7563 - val_loss: 0.5180 - val_accuracy: 0.7508
# Epoch 40/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5177 - accuracy: 0.7565 - val_loss: 0.5170 - val_accuracy: 0.7557
# Epoch 41/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5293 - accuracy: 0.7518 - val_loss: 0.5112 - val_accuracy: 0.7498
# Epoch 42/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5192 - accuracy: 0.7555 - val_loss: 0.5475 - val_accuracy: 0.7528
# Epoch 43/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5140 - accuracy: 0.7582 - val_loss: 0.5188 - val_accuracy: 0.7538
# Epoch 44/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5150 - accuracy: 0.7561 - val_loss: 0.5442 - val_accuracy: 0.7541
# Epoch 45/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5160 - accuracy: 0.7554 - val_loss: 0.5173 - val_accuracy: 0.7551
# Epoch 46/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5158 - accuracy: 0.7579 - val_loss: 0.5135 - val_accuracy: 0.7538
# Epoch 47/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5163 - accuracy: 0.7558 - val_loss: 0.5145 - val_accuracy: 0.7603
# Epoch 48/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5160 - accuracy: 0.7585 - val_loss: 0.5225 - val_accuracy: 0.7538
# Epoch 49/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5127 - accuracy: 0.7564 - val_loss: 0.5204 - val_accuracy: 0.7518
# Epoch 50/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5086 - accuracy: 0.7561 - val_loss: 0.5194 - val_accuracy: 0.7567

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - As we increased the depth of the neural network and changed the optimizer to Adam, we can see smoother loss curves for both train and validation.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat1 = model1.predict(X_test)

# keep probabilities for the positive outcome only
yhat1 = yhat1[:, 0]

# calculate roc curves
fpr, tpr, thresholds1 = roc_curve(y_test, yhat1)

# calculate the g-mean for each threshold
gmeans1 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans1)

print('Best Threshold=%f, G-Mean=%.3f' % (thresholds1[ix], gmeans1[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.185629, G-Mean=0.692

# %% [markdown]
# ### **Tuning the threshold using ROC-AUC**

# %%
#Predicting the results using best as a threshold

y_pred_e1=model1.predict(X_test)
y_pred_e1 = (y_pred_e1 > thresholds1[ix])
y_pred_e1
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test, y_pred_e1)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm1, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 

from sklearn import metrics
cr=metrics.classification_report(y_test,y_pred_e1)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77      2877
#            1       0.43      0.69      0.53       955
#
#     accuracy                           0.69      3832
#    macro avg       0.65      0.69      0.65      3832
# weighted avg       0.76      0.69      0.71      3832

# %% [markdown]
# - As the number of layers in the neural network has increased, we can see that the macro F1 score has increased, and the False Negative percentage has decreased.

# %% [markdown]
# ## **Model 3**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model2 = Sequential()
model2.add(Dense(128, activation = 'relu', input_dim = X_train.shape[1]))
model2.add(BatchNormalization())
model2.add(Dense(64, activation = 'relu', kernel_initializer = 'he_uniform'))
model2.add(BatchNormalization())
model2.add(Dense(32, activation = 'relu', kernel_initializer = 'he_uniform'))
model2.add(Dense(1, activation = 'sigmoid'))

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1280
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,417
# Trainable params: 12,033
# Non-trainable params: 384
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_2 = model2.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 3s 5ms/step - loss: 0.5698 - accuracy: 0.7403 - val_loss: 0.5690 - val_accuracy: 0.7515
# Epoch 2/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5438 - accuracy: 0.7499 - val_loss: 0.5367 - val_accuracy: 0.7577
# Epoch 3/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5368 - accuracy: 0.7511 - val_loss: 0.5421 - val_accuracy: 0.7564
# Epoch 4/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5160 - accuracy: 0.7551 - val_loss: 0.5144 - val_accuracy: 0.7674
# Epoch 5/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5061 - accuracy: 0.7625 - val_loss: 0.5036 - val_accuracy: 0.7645
# Epoch 6/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5055 - accuracy: 0.7595 - val_loss: 0.5025 - val_accuracy: 0.7710
# Epoch 7/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5019 - accuracy: 0.7622 - val_loss: 0.5167 - val_accuracy: 0.7472
# Epoch 8/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.5012 - accuracy: 0.7649 - val_loss: 0.5087 - val_accuracy: 0.7645
# Epoch 9/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4976 - accuracy: 0.7653 - val_loss: 0.5006 - val_accuracy: 0.7668
# Epoch 10/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4994 - accuracy: 0.7630 - val_loss: 0.4984 - val_accuracy: 0.7727
# Epoch 11/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4952 - accuracy: 0.7658 - val_loss: 0.4964 - val_accuracy: 0.7583
# Epoch 12/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4934 - accuracy: 0.7644 - val_loss: 0.5161 - val_accuracy: 0.7639
# Epoch 13/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4941 - accuracy: 0.7679 - val_loss: 0.4959 - val_accuracy: 0.7639
# Epoch 14/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4933 - accuracy: 0.7691 - val_loss: 0.4971 - val_accuracy: 0.7586
# Epoch 15/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4938 - accuracy: 0.7658 - val_loss: 0.4963 - val_accuracy: 0.7674
# Epoch 16/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4928 - accuracy: 0.7686 - val_loss: 0.4931 - val_accuracy: 0.7671
# Epoch 17/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4936 - accuracy: 0.7676 - val_loss: 0.4981 - val_accuracy: 0.7665
# Epoch 18/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4911 - accuracy: 0.7691 - val_loss: 0.5018 - val_accuracy: 0.7645
# Epoch 19/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4928 - accuracy: 0.7684 - val_loss: 0.4950 - val_accuracy: 0.7622
# Epoch 20/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4922 - accuracy: 0.7670 - val_loss: 0.5037 - val_accuracy: 0.7603
# Epoch 21/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4898 - accuracy: 0.7710 - val_loss: 0.5534 - val_accuracy: 0.7374
# Epoch 22/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4903 - accuracy: 0.7694 - val_loss: 0.5043 - val_accuracy: 0.7603
# Epoch 23/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4903 - accuracy: 0.7681 - val_loss: 0.4917 - val_accuracy: 0.7658
# Epoch 24/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4877 - accuracy: 0.7723 - val_loss: 0.4982 - val_accuracy: 0.7684
# Epoch 25/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4865 - accuracy: 0.7680 - val_loss: 0.5004 - val_accuracy: 0.7622
# Epoch 26/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4887 - accuracy: 0.7707 - val_loss: 0.5725 - val_accuracy: 0.7133
# Epoch 27/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4877 - accuracy: 0.7732 - val_loss: 0.4982 - val_accuracy: 0.7661
# Epoch 28/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4861 - accuracy: 0.7707 - val_loss: 0.4937 - val_accuracy: 0.7743
# Epoch 29/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4871 - accuracy: 0.7699 - val_loss: 0.5002 - val_accuracy: 0.7681
# Epoch 30/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4858 - accuracy: 0.7711 - val_loss: 0.4943 - val_accuracy: 0.7603
# Epoch 31/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4842 - accuracy: 0.7750 - val_loss: 0.4929 - val_accuracy: 0.7681
# Epoch 32/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4858 - accuracy: 0.7695 - val_loss: 0.5051 - val_accuracy: 0.7648
# Epoch 33/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4853 - accuracy: 0.7727 - val_loss: 0.5068 - val_accuracy: 0.7613
# Epoch 34/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4857 - accuracy: 0.7710 - val_loss: 0.5126 - val_accuracy: 0.7557
# Epoch 35/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4831 - accuracy: 0.7736 - val_loss: 0.5023 - val_accuracy: 0.7658
# Epoch 36/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4845 - accuracy: 0.7720 - val_loss: 0.4988 - val_accuracy: 0.7632
# Epoch 37/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4826 - accuracy: 0.7697 - val_loss: 0.4986 - val_accuracy: 0.7658
# Epoch 38/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4832 - accuracy: 0.7741 - val_loss: 0.5143 - val_accuracy: 0.7710
# Epoch 39/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4830 - accuracy: 0.7725 - val_loss: 0.5072 - val_accuracy: 0.7613
# Epoch 40/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4835 - accuracy: 0.7737 - val_loss: 0.4981 - val_accuracy: 0.7701
# Epoch 41/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4835 - accuracy: 0.7746 - val_loss: 0.4994 - val_accuracy: 0.7694
# Epoch 42/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4824 - accuracy: 0.7746 - val_loss: 0.5186 - val_accuracy: 0.7613
# Epoch 43/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4842 - accuracy: 0.7747 - val_loss: 0.5005 - val_accuracy: 0.7671
# Epoch 44/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4812 - accuracy: 0.7724 - val_loss: 0.4953 - val_accuracy: 0.7613
# Epoch 45/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4803 - accuracy: 0.7742 - val_loss: 0.5012 - val_accuracy: 0.7652
# Epoch 46/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4788 - accuracy: 0.7752 - val_loss: 0.5092 - val_accuracy: 0.7658
# Epoch 47/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4816 - accuracy: 0.7743 - val_loss: 0.5039 - val_accuracy: 0.7626
# Epoch 48/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4802 - accuracy: 0.7743 - val_loss: 0.4975 - val_accuracy: 0.7661
# Epoch 49/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4810 - accuracy: 0.7774 - val_loss: 0.5017 - val_accuracy: 0.7645
# Epoch 50/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4782 - accuracy: 0.7761 - val_loss: 0.4970 - val_accuracy: 0.7665

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - there is a lot of noise in the model, and it and seems to have overfitted on the training data because there is a significant difference in performance between train and validation.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat2 = model2.predict(X_test)

# keep probabilities for the positive outcome only
yhat2 = yhat2[:, 0]

# calculate roc curves
fpr, tpr, thresholds2 = roc_curve(y_test, yhat2)

# calculate the g-mean for each threshold
gmeans2 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans2)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds2[ix], gmeans2[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.267659, G-Mean=0.697

# %%
y_pred_e2=model2.predict(X_test)
y_pred_e2 = (y_pred_e2 > thresholds2[ix])
y_pred_e2
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm2=confusion_matrix(y_test, y_pred_e2)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm2, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 

from sklearn import metrics
cr2=metrics.classification_report(y_test,y_pred_e2)
print(cr2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81      2877
#            1       0.47      0.64      0.54       955
#
#     accuracy                           0.73      3832
#    macro avg       0.67      0.70      0.67      3832
# weighted avg       0.77      0.73      0.74      3832

# %% [markdown]
# - The Train and Validation curves seem to show overfitting despite having a good F1 score and a low False Negative rate.

# %% [markdown]
# ## **Model 4**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model3 = Sequential()
model3.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
model3.add(Dropout(0.2))
model3.add(Dense(128,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(64,activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(32,activation='relu'))
model3.add(Dense(1, activation = 'sigmoid'))

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2560
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_3 = model3.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 3s 6ms/step - loss: 0.6613 - accuracy: 0.7186 - val_loss: 0.5839 - val_accuracy: 0.7515
# Epoch 2/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5803 - accuracy: 0.7481 - val_loss: 0.5729 - val_accuracy: 0.7515
# Epoch 3/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5701 - accuracy: 0.7498 - val_loss: 0.5580 - val_accuracy: 0.7515
# Epoch 4/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5630 - accuracy: 0.7500 - val_loss: 0.5552 - val_accuracy: 0.7515
# Epoch 5/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5585 - accuracy: 0.7502 - val_loss: 0.5540 - val_accuracy: 0.7515
# Epoch 6/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5594 - accuracy: 0.7495 - val_loss: 0.5588 - val_accuracy: 0.7515
# Epoch 7/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5536 - accuracy: 0.7504 - val_loss: 0.5445 - val_accuracy: 0.7515
# Epoch 8/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5522 - accuracy: 0.7501 - val_loss: 0.5518 - val_accuracy: 0.7515
# Epoch 9/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5515 - accuracy: 0.7497 - val_loss: 0.5391 - val_accuracy: 0.7515
# Epoch 10/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5469 - accuracy: 0.7506 - val_loss: 0.5377 - val_accuracy: 0.7515
# Epoch 11/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5457 - accuracy: 0.7509 - val_loss: 0.5480 - val_accuracy: 0.7515
# Epoch 12/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5433 - accuracy: 0.7498 - val_loss: 0.5378 - val_accuracy: 0.7515
# Epoch 13/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5449 - accuracy: 0.7496 - val_loss: 0.5322 - val_accuracy: 0.7515
# Epoch 14/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5402 - accuracy: 0.7496 - val_loss: 0.5363 - val_accuracy: 0.7515
# Epoch 15/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5405 - accuracy: 0.7501 - val_loss: 0.5393 - val_accuracy: 0.7378
# Epoch 16/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5405 - accuracy: 0.7504 - val_loss: 0.5318 - val_accuracy: 0.7515
# Epoch 17/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5362 - accuracy: 0.7513 - val_loss: 0.5281 - val_accuracy: 0.7518
# Epoch 18/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5344 - accuracy: 0.7515 - val_loss: 0.5311 - val_accuracy: 0.7511
# Epoch 19/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5323 - accuracy: 0.7507 - val_loss: 0.5222 - val_accuracy: 0.7544
# Epoch 20/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5314 - accuracy: 0.7530 - val_loss: 0.5213 - val_accuracy: 0.7524
# Epoch 21/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5257 - accuracy: 0.7511 - val_loss: 0.5203 - val_accuracy: 0.7570
# Epoch 22/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5228 - accuracy: 0.7519 - val_loss: 0.5139 - val_accuracy: 0.7547
# Epoch 23/50
# 192/192 [==============================] - 1s 8ms/step - loss: 0.5210 - accuracy: 0.7507 - val_loss: 0.5141 - val_accuracy: 0.7544
# Epoch 24/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5204 - accuracy: 0.7533 - val_loss: 0.5049 - val_accuracy: 0.7567
# Epoch 25/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5173 - accuracy: 0.7568 - val_loss: 0.5105 - val_accuracy: 0.7655
# Epoch 26/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5143 - accuracy: 0.7563 - val_loss: 0.5104 - val_accuracy: 0.7599
# Epoch 27/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5136 - accuracy: 0.7561 - val_loss: 0.4998 - val_accuracy: 0.7688
# Epoch 28/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5156 - accuracy: 0.7585 - val_loss: 0.5062 - val_accuracy: 0.7733
# Epoch 29/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5096 - accuracy: 0.7600 - val_loss: 0.5107 - val_accuracy: 0.7577
# Epoch 30/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5097 - accuracy: 0.7613 - val_loss: 0.5025 - val_accuracy: 0.7701
# Epoch 31/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5078 - accuracy: 0.7602 - val_loss: 0.5035 - val_accuracy: 0.7635
# Epoch 32/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5073 - accuracy: 0.7606 - val_loss: 0.5115 - val_accuracy: 0.7694
# Epoch 33/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5053 - accuracy: 0.7609 - val_loss: 0.5091 - val_accuracy: 0.7678
# Epoch 34/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5081 - accuracy: 0.7599 - val_loss: 0.5053 - val_accuracy: 0.7717
# Epoch 35/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5030 - accuracy: 0.7651 - val_loss: 0.4989 - val_accuracy: 0.7688
# Epoch 36/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5029 - accuracy: 0.7655 - val_loss: 0.4987 - val_accuracy: 0.7707
# Epoch 37/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5031 - accuracy: 0.7628 - val_loss: 0.5069 - val_accuracy: 0.7606
# Epoch 38/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5034 - accuracy: 0.7628 - val_loss: 0.5048 - val_accuracy: 0.7632
# Epoch 39/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5028 - accuracy: 0.7654 - val_loss: 0.4991 - val_accuracy: 0.7626
# Epoch 40/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5015 - accuracy: 0.7641 - val_loss: 0.5016 - val_accuracy: 0.7691
# Epoch 41/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4987 - accuracy: 0.7643 - val_loss: 0.5141 - val_accuracy: 0.7622
# Epoch 42/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5015 - accuracy: 0.7644 - val_loss: 0.5021 - val_accuracy: 0.7668
# Epoch 43/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4983 - accuracy: 0.7679 - val_loss: 0.4949 - val_accuracy: 0.7691
# Epoch 44/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4982 - accuracy: 0.7624 - val_loss: 0.4995 - val_accuracy: 0.7678
# Epoch 45/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4986 - accuracy: 0.7644 - val_loss: 0.5000 - val_accuracy: 0.7733
# Epoch 46/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4995 - accuracy: 0.7666 - val_loss: 0.5041 - val_accuracy: 0.7622
# Epoch 47/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5000 - accuracy: 0.7637 - val_loss: 0.5029 - val_accuracy: 0.7704
# Epoch 48/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4966 - accuracy: 0.7676 - val_loss: 0.4947 - val_accuracy: 0.7684
# Epoch 49/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4958 - accuracy: 0.7655 - val_loss: 0.4994 - val_accuracy: 0.7681
# Epoch 50/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4952 - accuracy: 0.7692 - val_loss: 0.4984 - val_accuracy: 0.7733

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - both the curves train and validation are smooth.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat3 = model3.predict(X_test)

# keep probabilities for the positive outcome only
yhat3 = yhat3[:, 0]

# calculate roc curves
fpr, tpr, thresholds3 = roc_curve(y_test, yhat3)

# calculate the g-mean for each threshold
gmeans3 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans3)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds3[ix], gmeans3[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.235277, G-Mean=0.703

# %%
y_pred_e3=model3.predict(X_test)
y_pred_e3 = (y_pred_e3 > thresholds3[ix])
y_pred_e3
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm3=confusion_matrix(y_test, y_pred_e3)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm3, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
# Accuracy as per classification report

from sklearn import metrics
cr3 = metrics.classification_report(y_test, y_pred_e3)
print(cr3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80      2877
#            1       0.46      0.67      0.54       955
#
#     accuracy                           0.72      3832
#    macro avg       0.66      0.70      0.67      3832
# weighted avg       0.77      0.72      0.74      3832

# %% [markdown]
# - The Dropout technique helped the model reduce the loss function of both train and validation. The F1 score also seems to be fine, with a decrease in the False Negative rate.

# %% [markdown]
# ## **Model 5**
# - **Random Search CV**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v4(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))

    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %% [markdown]
# - using Random search to optimize two hyperparameters - Batch size & Learning Rate.

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v4, verbose=1)

# define the grid search parameters
param_random = {
    'batch_size':[32, 64, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
random= RandomizedSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_distributions=param_random,n_jobs=-1)

# %%
random_result = random.fit(X_train, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_))
means = random_result.cv_results_['mean_test_score']
stds = random_result.cv_results_['std_test_score']
params = random_result.cv_results_['params']
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 384/384 [==============================] - 2s 4ms/step - loss: 0.6441 - accuracy: 0.7414 - val_loss: 0.5620 - val_accuracy: 0.7515
# Best: 0.750620 using {'lr': 0.01, 'batch_size': 32}

# %% [markdown]
# #### **Result of Random Search**
# - {'batch_size': 32, 'learning_rate": 0.01}

# %%
estimator_v4=create_model_v4(batch_size=random_result.best_params_['batch_size'],lr=random_result.best_params_['lr'])
estimator_v4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2560
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(random_result.best_params_['lr'])
estimator_v4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_4=estimator_v4.fit(X_train, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.6643 - accuracy: 0.7405 - val_loss: 0.5677 - val_accuracy: 0.7515
# Epoch 2/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5643 - accuracy: 0.7502 - val_loss: 0.5600 - val_accuracy: 0.7515
# Epoch 3/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5594 - accuracy: 0.7502 - val_loss: 0.5468 - val_accuracy: 0.7515
# Epoch 4/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5569 - accuracy: 0.7503 - val_loss: 0.5447 - val_accuracy: 0.7515
# Epoch 5/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5528 - accuracy: 0.7504 - val_loss: 0.5525 - val_accuracy: 0.7515
# Epoch 6/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5538 - accuracy: 0.7498 - val_loss: 0.5443 - val_accuracy: 0.7515
# Epoch 7/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5521 - accuracy: 0.7499 - val_loss: 0.5401 - val_accuracy: 0.7515
# Epoch 8/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5511 - accuracy: 0.7502 - val_loss: 0.5448 - val_accuracy: 0.7515
# Epoch 9/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5510 - accuracy: 0.7502 - val_loss: 0.5452 - val_accuracy: 0.7515
# Epoch 10/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5515 - accuracy: 0.7504 - val_loss: 0.5379 - val_accuracy: 0.7515
# Epoch 11/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5502 - accuracy: 0.7501 - val_loss: 0.5611 - val_accuracy: 0.7515
# Epoch 12/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5499 - accuracy: 0.7504 - val_loss: 0.5431 - val_accuracy: 0.7515
# Epoch 13/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5510 - accuracy: 0.7504 - val_loss: 0.5353 - val_accuracy: 0.7515
# Epoch 14/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5469 - accuracy: 0.7504 - val_loss: 0.5431 - val_accuracy: 0.7515
# Epoch 15/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5481 - accuracy: 0.7502 - val_loss: 0.5414 - val_accuracy: 0.7515
# Epoch 16/50
# 192/192 [==============================] - 1s 8ms/step - loss: 0.5467 - accuracy: 0.7509 - val_loss: 0.5301 - val_accuracy: 0.7515
# Epoch 17/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5468 - accuracy: 0.7507 - val_loss: 0.5385 - val_accuracy: 0.7515
# Epoch 18/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5434 - accuracy: 0.7497 - val_loss: 0.5302 - val_accuracy: 0.7515
# Epoch 19/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5448 - accuracy: 0.7496 - val_loss: 0.5290 - val_accuracy: 0.7515
# Epoch 20/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5472 - accuracy: 0.7496 - val_loss: 0.5325 - val_accuracy: 0.7515
# Epoch 21/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5460 - accuracy: 0.7496 - val_loss: 0.5518 - val_accuracy: 0.7515
# Epoch 22/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5491 - accuracy: 0.7498 - val_loss: 0.5393 - val_accuracy: 0.7515
# Epoch 23/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5511 - accuracy: 0.7493 - val_loss: 0.5305 - val_accuracy: 0.7515
# Epoch 24/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5533 - accuracy: 0.7505 - val_loss: 0.5513 - val_accuracy: 0.7515
# Epoch 25/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5520 - accuracy: 0.7506 - val_loss: 0.5346 - val_accuracy: 0.7515
# Epoch 26/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5464 - accuracy: 0.7497 - val_loss: 0.5358 - val_accuracy: 0.7515
# Epoch 27/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5488 - accuracy: 0.7512 - val_loss: 0.5334 - val_accuracy: 0.7515
# Epoch 28/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5451 - accuracy: 0.7502 - val_loss: 0.5322 - val_accuracy: 0.7515
# Epoch 29/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5507 - accuracy: 0.7497 - val_loss: 0.5486 - val_accuracy: 0.7515
# Epoch 30/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5548 - accuracy: 0.7499 - val_loss: 0.5363 - val_accuracy: 0.7515
# Epoch 31/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5468 - accuracy: 0.7507 - val_loss: 0.5487 - val_accuracy: 0.7283
# Epoch 32/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5456 - accuracy: 0.7507 - val_loss: 0.5274 - val_accuracy: 0.7515
# Epoch 33/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5441 - accuracy: 0.7494 - val_loss: 0.5266 - val_accuracy: 0.7521
# Epoch 34/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5453 - accuracy: 0.7508 - val_loss: 0.5295 - val_accuracy: 0.7515
# Epoch 35/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5448 - accuracy: 0.7514 - val_loss: 0.5263 - val_accuracy: 0.7515
# Epoch 36/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5413 - accuracy: 0.7520 - val_loss: 0.5236 - val_accuracy: 0.7515
# Epoch 37/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5466 - accuracy: 0.7524 - val_loss: 0.5418 - val_accuracy: 0.7515
# Epoch 38/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5461 - accuracy: 0.7497 - val_loss: 0.5440 - val_accuracy: 0.7515
# Epoch 39/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5490 - accuracy: 0.7504 - val_loss: 0.5310 - val_accuracy: 0.7515
# Epoch 40/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5449 - accuracy: 0.7493 - val_loss: 0.5284 - val_accuracy: 0.7515
# Epoch 41/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5456 - accuracy: 0.7498 - val_loss: 0.5268 - val_accuracy: 0.7515
# Epoch 42/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5449 - accuracy: 0.7495 - val_loss: 0.5277 - val_accuracy: 0.7521
# Epoch 43/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5461 - accuracy: 0.7511 - val_loss: 0.5459 - val_accuracy: 0.7515
# Epoch 44/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5483 - accuracy: 0.7489 - val_loss: 0.5378 - val_accuracy: 0.7515
# Epoch 45/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5475 - accuracy: 0.7529 - val_loss: 0.5520 - val_accuracy: 0.7515
# Epoch 46/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5448 - accuracy: 0.7532 - val_loss: 0.5302 - val_accuracy: 0.7515
# Epoch 47/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5463 - accuracy: 0.7519 - val_loss: 0.5454 - val_accuracy: 0.7518
# Epoch 48/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5481 - accuracy: 0.7529 - val_loss: 0.5684 - val_accuracy: 0.7515
# Epoch 49/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5592 - accuracy: 0.7508 - val_loss: 0.5592 - val_accuracy: 0.7521
# Epoch 50/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5484 - accuracy: 0.7515 - val_loss: 0.5388 - val_accuracy: 0.7515

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# -  there is noise in the training behavior of the model.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat4 = estimator_v4.predict(X_test)

# keep probabilities for the positive outcome only
yhat4 = yhat4[:, 0]

# calculate roc curves
fpr, tpr, thresholds4 = roc_curve(y_test, yhat4)

# calculate the g-mean for each threshold
gmeans4 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans4)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds4[ix], gmeans4[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.196752, G-Mean=0.636

# %%
y_pred_e4=estimator_v4.predict(X_test)
y_pred_e4 = (y_pred_e4 > thresholds4[ix])
y_pred_e4
# Out:
# 120/120 [==============================] - 0s 1ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test, y_pred_e4)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm4, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 

from sklearn import metrics
cr4=metrics.classification_report(y_test,y_pred_e4)
print(cr4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.60      0.70      2877
#            1       0.36      0.67      0.47       955
#
#     accuracy                           0.62      3832
#    macro avg       0.60      0.64      0.59      3832
# weighted avg       0.73      0.62      0.64      3832

# %% [markdown]
# - the F1 score of the model has decreased in comparison to the previous best performance, as Random Search CV will choose the hyperparameters randomly, and hence has a very low chance of finding a highly optimal configuration.

# %% [markdown]
# ## **Model 6**
# - **Grid Search CV**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v5(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))

    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %% [markdown]
# - using Grid Search to optimize two hyperparameters - Batch Size & Learning Rate.

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v5, verbose=1)

# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.01,0.1,0.001],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()

grid_result = grid.fit(X_train, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

time.sleep(1)

# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 192/192 [==============================] - 2s 5ms/step - loss: 0.6800 - accuracy: 0.7375 - val_loss: 0.5677 - val_accuracy: 0.7515
# Best: 0.750620 using {'batch_size': 64, 'lr': 0.01}
# Total runtime of the program is 54.018248558044434

# %% [markdown]
# #### **Result of Grid Search**
# - {'batch_size': 64, 'learning_rate": 0.01}

# %%
estimator_v5=create_model_v5(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])
estimator_v5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2560
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_5=estimator_v5.fit(X_train, y_train, epochs=50, batch_size = 64, verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 3s 8ms/step - loss: 0.6643 - accuracy: 0.7405 - val_loss: 0.5677 - val_accuracy: 0.7515
# Epoch 2/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5643 - accuracy: 0.7502 - val_loss: 0.5600 - val_accuracy: 0.7515
# Epoch 3/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5594 - accuracy: 0.7502 - val_loss: 0.5468 - val_accuracy: 0.7515
# Epoch 4/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5569 - accuracy: 0.7503 - val_loss: 0.5447 - val_accuracy: 0.7515
# Epoch 5/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5528 - accuracy: 0.7504 - val_loss: 0.5525 - val_accuracy: 0.7515
# Epoch 6/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5538 - accuracy: 0.7498 - val_loss: 0.5443 - val_accuracy: 0.7515
# Epoch 7/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5521 - accuracy: 0.7499 - val_loss: 0.5401 - val_accuracy: 0.7515
# Epoch 8/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5511 - accuracy: 0.7502 - val_loss: 0.5448 - val_accuracy: 0.7515
# Epoch 9/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5510 - accuracy: 0.7502 - val_loss: 0.5452 - val_accuracy: 0.7515
# Epoch 10/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5515 - accuracy: 0.7504 - val_loss: 0.5379 - val_accuracy: 0.7515
# Epoch 11/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5502 - accuracy: 0.7501 - val_loss: 0.5611 - val_accuracy: 0.7515
# Epoch 12/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5499 - accuracy: 0.7504 - val_loss: 0.5431 - val_accuracy: 0.7515
# Epoch 13/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5510 - accuracy: 0.7504 - val_loss: 0.5353 - val_accuracy: 0.7515
# Epoch 14/50
# 192/192 [==============================] - 1s 8ms/step - loss: 0.5469 - accuracy: 0.7504 - val_loss: 0.5431 - val_accuracy: 0.7515
# Epoch 15/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5481 - accuracy: 0.7502 - val_loss: 0.5414 - val_accuracy: 0.7515
# Epoch 16/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5467 - accuracy: 0.7509 - val_loss: 0.5301 - val_accuracy: 0.7515
# Epoch 17/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5468 - accuracy: 0.7507 - val_loss: 0.5385 - val_accuracy: 0.7515
# Epoch 18/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5434 - accuracy: 0.7497 - val_loss: 0.5302 - val_accuracy: 0.7515
# Epoch 19/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5448 - accuracy: 0.7496 - val_loss: 0.5290 - val_accuracy: 0.7515
# Epoch 20/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5472 - accuracy: 0.7496 - val_loss: 0.5325 - val_accuracy: 0.7515
# Epoch 21/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5460 - accuracy: 0.7496 - val_loss: 0.5518 - val_accuracy: 0.7515
# Epoch 22/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5491 - accuracy: 0.7498 - val_loss: 0.5393 - val_accuracy: 0.7515
# Epoch 23/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5511 - accuracy: 0.7493 - val_loss: 0.5305 - val_accuracy: 0.7515
# Epoch 24/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5533 - accuracy: 0.7505 - val_loss: 0.5513 - val_accuracy: 0.7515
# Epoch 25/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5520 - accuracy: 0.7506 - val_loss: 0.5346 - val_accuracy: 0.7515
# Epoch 26/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5464 - accuracy: 0.7497 - val_loss: 0.5358 - val_accuracy: 0.7515
# Epoch 27/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5488 - accuracy: 0.7512 - val_loss: 0.5334 - val_accuracy: 0.7515
# Epoch 28/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5451 - accuracy: 0.7502 - val_loss: 0.5322 - val_accuracy: 0.7515
# Epoch 29/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5507 - accuracy: 0.7497 - val_loss: 0.5486 - val_accuracy: 0.7515
# Epoch 30/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5548 - accuracy: 0.7499 - val_loss: 0.5363 - val_accuracy: 0.7515
# Epoch 31/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5468 - accuracy: 0.7507 - val_loss: 0.5487 - val_accuracy: 0.7283
# Epoch 32/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5456 - accuracy: 0.7507 - val_loss: 0.5274 - val_accuracy: 0.7515
# Epoch 33/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5441 - accuracy: 0.7494 - val_loss: 0.5266 - val_accuracy: 0.7521
# Epoch 34/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5453 - accuracy: 0.7508 - val_loss: 0.5295 - val_accuracy: 0.7515
# Epoch 35/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5448 - accuracy: 0.7514 - val_loss: 0.5263 - val_accuracy: 0.7515
# Epoch 36/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5413 - accuracy: 0.7520 - val_loss: 0.5236 - val_accuracy: 0.7515
# Epoch 37/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5466 - accuracy: 0.7524 - val_loss: 0.5418 - val_accuracy: 0.7515
# Epoch 38/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5461 - accuracy: 0.7497 - val_loss: 0.5440 - val_accuracy: 0.7515
# Epoch 39/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5490 - accuracy: 0.7504 - val_loss: 0.5310 - val_accuracy: 0.7515
# Epoch 40/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5449 - accuracy: 0.7493 - val_loss: 0.5284 - val_accuracy: 0.7515
# Epoch 41/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5456 - accuracy: 0.7498 - val_loss: 0.5268 - val_accuracy: 0.7515
# Epoch 42/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5449 - accuracy: 0.7495 - val_loss: 0.5277 - val_accuracy: 0.7521
# Epoch 43/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5461 - accuracy: 0.7511 - val_loss: 0.5459 - val_accuracy: 0.7515
# Epoch 44/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5483 - accuracy: 0.7489 - val_loss: 0.5378 - val_accuracy: 0.7515
# Epoch 45/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5475 - accuracy: 0.7529 - val_loss: 0.5520 - val_accuracy: 0.7515
# Epoch 46/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5448 - accuracy: 0.7532 - val_loss: 0.5302 - val_accuracy: 0.7515
# Epoch 47/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5463 - accuracy: 0.7519 - val_loss: 0.5454 - val_accuracy: 0.7518
# Epoch 48/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5481 - accuracy: 0.7529 - val_loss: 0.5684 - val_accuracy: 0.7515
# Epoch 49/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5592 - accuracy: 0.7508 - val_loss: 0.5592 - val_accuracy: 0.7521
# Epoch 50/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5484 - accuracy: 0.7515 - val_loss: 0.5388 - val_accuracy: 0.7515

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - both curves - train and validation, are smooth.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat5 = estimator_v5.predict(X_test)

# keep probabilities for the positive outcome only
yhat5 = yhat5[:, 0]

# calculate roc curves
fpr, tpr, thresholds5 = roc_curve(y_test, yhat5)

# calculate the g-mean for each threshold
gmeans5 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans5)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds5[ix], gmeans5[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.196752, G-Mean=0.636

# %%
y_pred_e5=estimator_v5.predict(X_test)
y_pred_e5 = (y_pred_e5 > thresholds5[ix])
y_pred_e5
# Out:
# 120/120 [==============================] - 0s 1ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm5=confusion_matrix(y_test, y_pred_e5)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm5, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
#Accuracy as per the classification report 

from sklearn import metrics
cr5=metrics.classification_report(y_test,y_pred_e5)
print(cr5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.60      0.70      2877
#            1       0.36      0.67      0.47       955
#
#     accuracy                           0.62      3832
#    macro avg       0.60      0.64      0.59      3832
# weighted avg       0.73      0.62      0.64      3832

# %% [markdown]
# - the F1 score of the model, while better than in Randomized Search, is slightly lower than in Model 4 (the Dropout model).

# %% [markdown]
# ## **Dask**
# - provide a performance boost to Hyperparameter Tuning due to its parallelized computing procedure.

# %%
# !pip install dask-ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dask-ml
#   Downloading dask_ml-2022.5.27-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 14.9 MB/s
# Requirement already satisfied: dask[array,dataframe]>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (2022.2.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from dask-ml) (21.3)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (0.56.3)
# Requirement already satisfied: multipledispatch>=0.4.9 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dask-ml) (1.7.3)
# Collecting dask-glm>=0.2.0
#   Downloading dask_glm-0.2.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: distributed>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (2022.2.0)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from dask-ml) (1.3.5)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from dask-glm>=0.2.0->dask-ml) (1.5.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (2022.10.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (1.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (2.11.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (7.1.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (57.4.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (1.0.4)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (2.2.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (5.4.8)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.4.0->dask-ml) (5.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from multipledispatch>=0.4.9->dask-ml) (1.15.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51.0->dask-ml) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba>=0.51.0->dask-ml) (4.13.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->dask-ml) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->dask-ml) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.2->dask-ml) (2.8.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[array,dataframe]>=2.4.0->dask-ml) (1.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->dask-ml) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->dask-ml) (3.1.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.4.0->dask-ml) (1.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.51.0->dask-ml) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.51.0->dask-ml) (3.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.4.0->dask-ml) (2.0.1)
# Installing collected packages: dask-glm, dask-ml
# Successfully installed dask-glm-0.2.0 dask-ml-2022.5.27

# %%
from dask_ml.model_selection import GridSearchCV as DaskGridSearchCV

# %%
def create_model_v6(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))

    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v6, verbose=1)

# define the grid search parameters
param_grid = {
    'batch_size':[64,32, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
dask = DaskGridSearchCV(estimator=keras_estimator, 
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)

# %%
import time
  
# store starting time
begin = time.time()
dask_result = dask.fit(X_train, y_train,validation_split=0.2,verbose=1) 

# Summarize results
print("Best: %f using %s" % (dask_result.best_score_, dask_result.best_params_))
means = dask_result.cv_results_['mean_test_score']
stds = dask_result.cv_results_['std_test_score']
params = dask_result.cv_results_['params']
time.sleep(1)

# store end time
end = time.time()
  
# total time taken
print(f"Total runtime of the program is {end - begin}")
# Out:
# 128/128 [==============================] - 5s 17ms/step - loss: 0.6741 - accuracy: 0.7133 - val_loss: 0.5925 - val_accuracy: 0.7529
# 128/128 [==============================] - 5s 17ms/step - loss: 0.7401 - accuracy: 0.6947 - val_loss: 0.5818 - val_accuracy: 0.7529
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5816 - accuracy: 0.7553
# 80/80 [==============================] - 1s 5ms/step - loss: 0.5933 - accuracy: 0.7473
# 128/128 [==============================] - 3s 11ms/step - loss: 0.6980 - accuracy: 0.7075 - val_loss: 0.5936 - val_accuracy: 0.7568
# 128/128 [==============================] - 3s 11ms/step - loss: 0.6226 - accuracy: 0.7351 - val_loss: 0.5558 - val_accuracy: 0.7529
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.7492
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5543 - accuracy: 0.7553
# 128/128 [==============================] - 2s 7ms/step - loss: 0.6810 - accuracy: 0.7385 - val_loss: 0.5653 - val_accuracy: 0.7529
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5700 - accuracy: 0.7473
# 128/128 [==============================] - 3s 10ms/step - loss: 5.0494 - accuracy: 0.7437 - val_loss: 0.5595 - val_accuracy: 0.7529
# 128/128 [==============================] - 3s 11ms/step - loss: 0.7047 - accuracy: 0.7331 - val_loss: 0.5818 - val_accuracy: 0.7568
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5570 - accuracy: 0.7553
# 80/80 [==============================] - 0s 4ms/step - loss: 0.5865 - accuracy: 0.7492
# 128/128 [==============================] - 3s 10ms/step - loss: 7.2376 - accuracy: 0.7467 - val_loss: 0.5596 - val_accuracy: 0.7529
# 128/128 [==============================] - 3s 8ms/step - loss: 5.9641 - accuracy: 0.7457 - val_loss: 0.5554 - val_accuracy: 0.7568
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7492
# 80/80 [==============================] - 0s 5ms/step - loss: 0.5654 - accuracy: 0.7473
# 256/256 [==============================] - 3s 8ms/step - loss: 0.6900 - accuracy: 0.7103 - val_loss: 0.6013 - val_accuracy: 0.7529
# 160/160 [==============================] - 1s 4ms/step - loss: 0.6018 - accuracy: 0.7553
# 256/256 [==============================] - 4s 6ms/step - loss: 0.6866 - accuracy: 0.7168 - val_loss: 0.5978 - val_accuracy: 0.7529
# 160/160 [==============================] - 1s 4ms/step - loss: 0.6011 - accuracy: 0.7473
# 256/256 [==============================] - 2s 5ms/step - loss: 0.6857 - accuracy: 0.7190 - val_loss: 0.5969 - val_accuracy: 0.7568
# 160/160 [==============================] - 1s 4ms/step - loss: 0.6029 - accuracy: 0.7492
# 256/256 [==============================] - 2s 5ms/step - loss: 0.6391 - accuracy: 0.7367 - val_loss: 0.5573 - val_accuracy: 0.7529
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5540 - accuracy: 0.7553
# 256/256 [==============================] - 3s 8ms/step - loss: 0.6462 - accuracy: 0.7399 - val_loss: 0.5534 - val_accuracy: 0.7529
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5603 - accuracy: 0.7473
# 256/256 [==============================] - 3s 7ms/step - loss: 0.6609 - accuracy: 0.7376 - val_loss: 0.5562 - val_accuracy: 0.7568
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5627 - accuracy: 0.7492
# 256/256 [==============================] - 2s 7ms/step - loss: 5.1917 - accuracy: 0.7401 - val_loss: 0.5592 - val_accuracy: 0.7529
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5566 - accuracy: 0.7553
# 256/256 [==============================] - 3s 6ms/step - loss: 2.1741 - accuracy: 0.7416 - val_loss: 0.5591 - val_accuracy: 0.7529
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5655 - accuracy: 0.7473
# 256/256 [==============================] - 4s 10ms/step - loss: 1.9891 - accuracy: 0.7460 - val_loss: 0.5566 - val_accuracy: 0.7568
# 64/64 [==============================] - 3s 9ms/step - loss: 0.8042 - accuracy: 0.6857 - val_loss: 0.6027 - val_accuracy: 0.7529
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.7553
# 64/64 [==============================] - 1s 8ms/step - loss: 0.7656 - accuracy: 0.7005 - val_loss: 0.5864 - val_accuracy: 0.7529
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5891 - accuracy: 0.7473
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5641 - accuracy: 0.7492
# 64/64 [==============================] - 2s 14ms/step - loss: 0.7357 - accuracy: 0.7012 - val_loss: 0.5827 - val_accuracy: 0.7568
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5896 - accuracy: 0.7492
# 64/64 [==============================] - 3s 18ms/step - loss: 0.7079 - accuracy: 0.7218 - val_loss: 0.5621 - val_accuracy: 0.7529
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5609 - accuracy: 0.7553
# 64/64 [==============================] - 3s 15ms/step - loss: 0.7835 - accuracy: 0.7275 - val_loss: 0.5700 - val_accuracy: 0.7529
# 64/64 [==============================] - 2s 15ms/step - loss: 0.7518 - accuracy: 0.7247 - val_loss: 0.5598 - val_accuracy: 0.7568
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5736 - accuracy: 0.7473
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5673 - accuracy: 0.7492
# 64/64 [==============================] - 2s 15ms/step - loss: 22.5693 - accuracy: 0.7417 - val_loss: 0.5598 - val_accuracy: 0.7529
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5573 - accuracy: 0.7553
# 64/64 [==============================] - 2s 12ms/step - loss: 11.4554 - accuracy: 0.7302 - val_loss: 0.5611 - val_accuracy: 0.7529
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5665 - accuracy: 0.7473
# 64/64 [==============================] - 1s 9ms/step - loss: 6.3777 - accuracy: 0.7343 - val_loss: 0.5556 - val_accuracy: 0.7568
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5635 - accuracy: 0.7492
# 192/192 [==============================] - 2s 5ms/step - loss: 0.6818 - accuracy: 0.7184 - val_loss: 0.5821 - val_accuracy: 0.7515
# Best: 0.750620 using {'batch_size': 64, 'lr': 0.001}
# Total runtime of the program is 59.0179443359375

# %% [markdown]
# - dataset dimensions and hyperparameter number/range were small for this example, Dask couldn't show a significant improvement.

# %% [markdown]
# ### **Keras Tuner**

# %%
# !pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 11.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.21.6)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.9.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (21.3)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 27.4 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.50.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.37.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.17.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (4.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.2)
# Installing collected packages: jedi, kt-legacy, keras-tuner
# Successfully installed jedi-0.18.1 keras-tuner-1.1.3 kt-legacy-1.0.4

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# #### **Hyperparameters**
# - How many hidden layers should the model have?
# - How many neurons should the model have in each hidden layer?
# - Learning Rate

# %%
def build_model(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective = 'val_accuracy',
    max_trials = 5,
    executions_per_trial = 3,
    project_name = 'Job')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
# Searching the best model on X and y train

tuner.search(X_train, y_train,
             epochs=5,
             validation_split = 0.2)
# Out:
# Trial 5 Complete [00h 00m 46s]
# val_accuracy: 0.7514677047729492
#
# Best val_accuracy So Far: 0.7514677047729492
# Total elapsed time: 00h 03m 11s

# %%
# Printing the best models with their hyperparameters

tuner.results_summary()
# Out:
# Results summary
# Results in ./Job
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f9db702e210>
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.7514677047729492
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.7514677047729492
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.7514677047729492
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.7514677047729492
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.7514677047729492

# %% [markdown]
# ## **Model 7**
# - using above mentioned best configuration given by keras tuner.

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model7 = Sequential()
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model7.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model7.add(Dense(1, activation = 'sigmoid'))

# %%
model7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               1600
#
#  dense_1 (Dense)             (None, 160)               25760
#
#  dense_2 (Dense)             (None, 224)               36064
#
#  dense_3 (Dense)             (None, 128)               28800
#
#  dense_4 (Dense)             (None, 224)               28896
#
#  dense_5 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 121,345
# Trainable params: 121,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(0.001)
model7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history_7 = model7.fit(X_train,y_train,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 4s 11ms/step - loss: 0.9531 - accuracy: 0.6972 - val_loss: 0.5616 - val_accuracy: 0.7511
# Epoch 2/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.6111 - accuracy: 0.7280 - val_loss: 0.5759 - val_accuracy: 0.7502
# Epoch 3/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5792 - accuracy: 0.7385 - val_loss: 0.5714 - val_accuracy: 0.7254
# Epoch 4/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5749 - accuracy: 0.7440 - val_loss: 0.5621 - val_accuracy: 0.7339
# Epoch 5/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5673 - accuracy: 0.7435 - val_loss: 0.5570 - val_accuracy: 0.7469
# Epoch 6/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5660 - accuracy: 0.7436 - val_loss: 0.5506 - val_accuracy: 0.7511
# Epoch 7/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5559 - accuracy: 0.7481 - val_loss: 0.5492 - val_accuracy: 0.7492
# Epoch 8/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5541 - accuracy: 0.7472 - val_loss: 0.5636 - val_accuracy: 0.7521
# Epoch 9/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5520 - accuracy: 0.7485 - val_loss: 0.5422 - val_accuracy: 0.7502
# Epoch 10/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5491 - accuracy: 0.7482 - val_loss: 0.5409 - val_accuracy: 0.7485
# Epoch 11/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5478 - accuracy: 0.7508 - val_loss: 0.5565 - val_accuracy: 0.7407
# Epoch 12/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5430 - accuracy: 0.7509 - val_loss: 0.5686 - val_accuracy: 0.7489
# Epoch 13/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5491 - accuracy: 0.7495 - val_loss: 0.5377 - val_accuracy: 0.7508
# Epoch 14/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5405 - accuracy: 0.7514 - val_loss: 0.5576 - val_accuracy: 0.7518
# Epoch 15/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5453 - accuracy: 0.7508 - val_loss: 0.5483 - val_accuracy: 0.7508
# Epoch 16/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5444 - accuracy: 0.7505 - val_loss: 0.5488 - val_accuracy: 0.7479
# Epoch 17/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5416 - accuracy: 0.7515 - val_loss: 0.5394 - val_accuracy: 0.7508
# Epoch 18/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5452 - accuracy: 0.7519 - val_loss: 0.5397 - val_accuracy: 0.7495
# Epoch 19/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5380 - accuracy: 0.7518 - val_loss: 0.5580 - val_accuracy: 0.7531
# Epoch 20/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5424 - accuracy: 0.7511 - val_loss: 0.5379 - val_accuracy: 0.7515
# Epoch 21/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5375 - accuracy: 0.7499 - val_loss: 0.5434 - val_accuracy: 0.7524
# Epoch 22/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5392 - accuracy: 0.7505 - val_loss: 0.5315 - val_accuracy: 0.7515
# Epoch 23/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5401 - accuracy: 0.7506 - val_loss: 0.5611 - val_accuracy: 0.7511
# Epoch 24/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5351 - accuracy: 0.7525 - val_loss: 0.5285 - val_accuracy: 0.7521
# Epoch 25/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5304 - accuracy: 0.7515 - val_loss: 0.5266 - val_accuracy: 0.7570
# Epoch 26/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5289 - accuracy: 0.7517 - val_loss: 0.5319 - val_accuracy: 0.7511
# Epoch 27/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5306 - accuracy: 0.7515 - val_loss: 0.5341 - val_accuracy: 0.7554
# Epoch 28/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5301 - accuracy: 0.7535 - val_loss: 0.5405 - val_accuracy: 0.7502
# Epoch 29/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5255 - accuracy: 0.7533 - val_loss: 0.5189 - val_accuracy: 0.7554
# Epoch 30/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5236 - accuracy: 0.7552 - val_loss: 0.5197 - val_accuracy: 0.7590
# Epoch 31/50
# 192/192 [==============================] - 2s 10ms/step - loss: 0.5187 - accuracy: 0.7572 - val_loss: 0.5178 - val_accuracy: 0.7613
# Epoch 32/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5181 - accuracy: 0.7563 - val_loss: 0.5141 - val_accuracy: 0.7551
# Epoch 33/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5192 - accuracy: 0.7523 - val_loss: 0.5260 - val_accuracy: 0.7528
# Epoch 34/50
# 192/192 [==============================] - 2s 12ms/step - loss: 0.5187 - accuracy: 0.7565 - val_loss: 0.5224 - val_accuracy: 0.7531
# Epoch 35/50
# 192/192 [==============================] - 2s 10ms/step - loss: 0.5166 - accuracy: 0.7548 - val_loss: 0.5436 - val_accuracy: 0.7528
# Epoch 36/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5139 - accuracy: 0.7572 - val_loss: 0.5246 - val_accuracy: 0.7723
# Epoch 37/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5113 - accuracy: 0.7560 - val_loss: 0.5174 - val_accuracy: 0.7652
# Epoch 38/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5097 - accuracy: 0.7608 - val_loss: 0.5153 - val_accuracy: 0.7541
# Epoch 39/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5134 - accuracy: 0.7562 - val_loss: 0.5217 - val_accuracy: 0.7489
# Epoch 40/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5103 - accuracy: 0.7594 - val_loss: 0.5202 - val_accuracy: 0.7547
# Epoch 41/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5087 - accuracy: 0.7616 - val_loss: 0.5197 - val_accuracy: 0.7570
# Epoch 42/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5110 - accuracy: 0.7594 - val_loss: 0.5350 - val_accuracy: 0.7599
# Epoch 43/50
# 192/192 [==============================] - 2s 8ms/step - loss: 0.5063 - accuracy: 0.7630 - val_loss: 0.5213 - val_accuracy: 0.7635
# Epoch 44/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5065 - accuracy: 0.7633 - val_loss: 0.5254 - val_accuracy: 0.7697
# Epoch 45/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5077 - accuracy: 0.7610 - val_loss: 0.5302 - val_accuracy: 0.7482
# Epoch 46/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5052 - accuracy: 0.7648 - val_loss: 0.5356 - val_accuracy: 0.7557
# Epoch 47/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5097 - accuracy: 0.7617 - val_loss: 0.5039 - val_accuracy: 0.7678
# Epoch 48/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5056 - accuracy: 0.7628 - val_loss: 0.5158 - val_accuracy: 0.7557
# Epoch 49/50
# 192/192 [==============================] - 2s 9ms/step - loss: 0.5040 - accuracy: 0.7631 - val_loss: 0.5452 - val_accuracy: 0.7531
# Epoch 50/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.5030 - accuracy: 0.7662 - val_loss: 0.5257 - val_accuracy: 0.7609

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - the train and validation curves are smooth.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat7 = model7.predict(X_test)

# keep probabilities for the positive outcome only
yhat7 = yhat7[:, 0]

# calculate roc curves
fpr, tpr, thresholds7 = roc_curve(y_test, yhat7)

# calculate the g-mean for each threshold
gmeans7 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans7)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds7[ix], gmeans7[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 3ms/step
# Best Threshold=0.215992, G-Mean=0.683

# %%
y_pred_e7=model7.predict(X_test)
y_pred_e7 = (y_pred_e7 > thresholds7[ix])
y_pred_e7
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm7=confusion_matrix(y_test, y_pred_e7)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm7, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
# Accuracy as per the classification report 

from sklearn import metrics
cr7=metrics.classification_report(y_test,y_pred_e7)
print(cr7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77      2877
#            1       0.42      0.67      0.52       955
#
#     accuracy                           0.69      3832
#    macro avg       0.64      0.68      0.64      3832
# weighted avg       0.75      0.69      0.71      3832

# %% [markdown]
# - After using the suggested hyperparameters from Keras Tuner, the F1 score has slightly increased, and the False Negative rate is higher in comparison to the previous optimization technique model.

# %% [markdown]
# ## **SMOTE + Keras Tuner**

# %%
# Applying SMOTE on train and test

from imblearn.over_sampling import SMOTE
smote=SMOTE(sampling_strategy='not majority')
X_sm , y_sm = smote.fit_resample(X_train,y_train)

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def build_model_2(h):
    model = keras.Sequential()
    for i in range(h.Int('num_layers', 2, 10)):
        model.add(layers.Dense(units=h.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=256,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            h.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model

# %%
tuner_2 = RandomSearch(
    build_model_2,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    project_name='Job_Switch')

# %%
tuner_2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner_2.search(X_sm, y_sm,
             epochs=5,
             validation_split = 0.2)
# Out:
# Trial 5 Complete [00h 01m 26s]
# val_accuracy: 0.28103724122047424
#
# Best val_accuracy So Far: 0.40467912952105206
# Total elapsed time: 00h 05m 04s

# %%
tuner_2.results_summary()
# Out:
# Results summary
# Results in ./Job_Switch
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f9dbb9aa890>
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 64
# units_1: 96
# learning_rate: 0.001
# units_2: 96
# units_3: 224
# units_4: 256
# units_5: 160
# units_6: 192
# units_7: 224
# units_8: 224
# Score: 0.40467912952105206
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 160
# units_1: 64
# learning_rate: 0.001
# units_2: 160
# units_3: 64
# units_4: 192
# units_5: 32
# units_6: 224
# units_7: 96
# units_8: 192
# Score: 0.40352020661036175
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 160
# units_1: 160
# learning_rate: 0.001
# units_2: 224
# units_3: 128
# units_4: 224
# units_5: 64
# units_6: 160
# units_7: 64
# units_8: 32
# Score: 0.39113428195317584
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 192
# units_1: 96
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# Score: 0.2905982881784439
# Trial summary
# Hyperparameters:
# num_layers: 9
# units_0: 128
# units_1: 32
# learning_rate: 0.0001
# units_2: 160
# units_3: 160
# units_4: 160
# units_5: 192
# units_6: 96
# units_7: 128
# units_8: 96
# Score: 0.28103724122047424

# %% [markdown]
# ## **Model 9**

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model9 = Sequential()
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform',input_dim = X_train.shape[1]))
model9.add(Dense(160,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(224,activation='relu',kernel_initializer='he_uniform'))
model9.add(Dense(1, activation = 'sigmoid'))

      #Compiling the ANN with Adam optimizer and binary cross entropy loss function 
optimizer = tf.keras.optimizers.Adam(0.001)
model9.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model9.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               1600
#
#  dense_1 (Dense)             (None, 160)               25760
#
#  dense_2 (Dense)             (None, 224)               36064
#
#  dense_3 (Dense)             (None, 128)               28800
#
#  dense_4 (Dense)             (None, 224)               28896
#
#  dense_5 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 121,345
# Trainable params: 121,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_9 = model9.fit(X_sm,y_sm,batch_size=64,epochs=50,verbose=1,validation_split = 0.2)
# Out:
# Epoch 1/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.9887 - accuracy: 0.5901 - val_loss: 1.0820 - val_accuracy: 0.0869
# Epoch 2/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.6620 - accuracy: 0.6233 - val_loss: 1.0869 - val_accuracy: 0.1421
# Epoch 3/50
# 288/288 [==============================] - 3s 10ms/step - loss: 0.6586 - accuracy: 0.6278 - val_loss: 1.5361 - val_accuracy: 0.0884
# Epoch 4/50
# 288/288 [==============================] - 3s 11ms/step - loss: 0.6532 - accuracy: 0.6291 - val_loss: 0.6423 - val_accuracy: 0.7027
# Epoch 5/50
# 288/288 [==============================] - 3s 11ms/step - loss: 0.6479 - accuracy: 0.6316 - val_loss: 0.9075 - val_accuracy: 0.1030
# Epoch 6/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.6458 - accuracy: 0.6320 - val_loss: 0.9713 - val_accuracy: 0.1454
# Epoch 7/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.6404 - accuracy: 0.6390 - val_loss: 1.0571 - val_accuracy: 0.1704
# Epoch 8/50
# 288/288 [==============================] - 3s 11ms/step - loss: 0.6398 - accuracy: 0.6420 - val_loss: 0.7650 - val_accuracy: 0.4020
# Epoch 9/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.6341 - accuracy: 0.6452 - val_loss: 0.8719 - val_accuracy: 0.2384
# Epoch 10/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6308 - accuracy: 0.6497 - val_loss: 0.9168 - val_accuracy: 0.3042
# Epoch 11/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6253 - accuracy: 0.6522 - val_loss: 0.9248 - val_accuracy: 0.2232
# Epoch 12/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6308 - accuracy: 0.6489 - val_loss: 1.0166 - val_accuracy: 0.1973
# Epoch 13/50
# 288/288 [==============================] - 2s 7ms/step - loss: 0.6215 - accuracy: 0.6601 - val_loss: 0.7203 - val_accuracy: 0.5617
# Epoch 14/50
# 288/288 [==============================] - 2s 7ms/step - loss: 0.6244 - accuracy: 0.6552 - val_loss: 0.9800 - val_accuracy: 0.1747
# Epoch 15/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.6170 - accuracy: 0.6594 - val_loss: 0.7165 - val_accuracy: 0.4930
# Epoch 16/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6157 - accuracy: 0.6650 - val_loss: 0.7844 - val_accuracy: 0.3896
# Epoch 17/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.6151 - accuracy: 0.6657 - val_loss: 0.7854 - val_accuracy: 0.3603
# Epoch 18/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6121 - accuracy: 0.6678 - val_loss: 0.9233 - val_accuracy: 0.2382
# Epoch 19/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.6069 - accuracy: 0.6741 - val_loss: 0.7725 - val_accuracy: 0.4807
# Epoch 20/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.6101 - accuracy: 0.6712 - val_loss: 0.7626 - val_accuracy: 0.4746
# Epoch 21/50
# 288/288 [==============================] - 2s 7ms/step - loss: 0.6040 - accuracy: 0.6754 - val_loss: 0.8821 - val_accuracy: 0.3116
# Epoch 22/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5989 - accuracy: 0.6841 - val_loss: 0.8474 - val_accuracy: 0.3372
# Epoch 23/50
# 288/288 [==============================] - 3s 11ms/step - loss: 0.6003 - accuracy: 0.6837 - val_loss: 0.8282 - val_accuracy: 0.4565
# Epoch 24/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5937 - accuracy: 0.6869 - val_loss: 0.9059 - val_accuracy: 0.3883
# Epoch 25/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5913 - accuracy: 0.6880 - val_loss: 1.1121 - val_accuracy: 0.2597
# Epoch 26/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5933 - accuracy: 0.6875 - val_loss: 0.8103 - val_accuracy: 0.5028
# Epoch 27/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5928 - accuracy: 0.6902 - val_loss: 0.8956 - val_accuracy: 0.3738
# Epoch 28/50
# 288/288 [==============================] - 2s 7ms/step - loss: 0.5884 - accuracy: 0.6915 - val_loss: 0.7616 - val_accuracy: 0.5598
# Epoch 29/50
# 288/288 [==============================] - 2s 7ms/step - loss: 0.5858 - accuracy: 0.6943 - val_loss: 1.0212 - val_accuracy: 0.2362
# Epoch 30/50
# 288/288 [==============================] - 2s 9ms/step - loss: 0.5802 - accuracy: 0.7004 - val_loss: 0.6915 - val_accuracy: 0.5628
# Epoch 31/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.5810 - accuracy: 0.6973 - val_loss: 0.6389 - val_accuracy: 0.6612
# Epoch 32/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5844 - accuracy: 0.6949 - val_loss: 0.6317 - val_accuracy: 0.6499
# Epoch 33/50
# 288/288 [==============================] - 3s 11ms/step - loss: 0.5783 - accuracy: 0.6994 - val_loss: 0.5679 - val_accuracy: 0.7792
# Epoch 34/50
# 288/288 [==============================] - 3s 10ms/step - loss: 0.5774 - accuracy: 0.7031 - val_loss: 0.7069 - val_accuracy: 0.5719
# Epoch 35/50
# 288/288 [==============================] - 3s 10ms/step - loss: 0.5815 - accuracy: 0.7005 - val_loss: 1.0370 - val_accuracy: 0.2983
# Epoch 36/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.5744 - accuracy: 0.7030 - val_loss: 0.6092 - val_accuracy: 0.7112
# Epoch 37/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5799 - accuracy: 0.6993 - val_loss: 0.8021 - val_accuracy: 0.3548
# Epoch 38/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.5745 - accuracy: 0.7041 - val_loss: 0.8684 - val_accuracy: 0.4096
# Epoch 39/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5765 - accuracy: 0.7032 - val_loss: 0.8475 - val_accuracy: 0.4481
# Epoch 40/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5709 - accuracy: 0.7090 - val_loss: 0.7487 - val_accuracy: 0.5261
# Epoch 41/50
# 288/288 [==============================] - 3s 12ms/step - loss: 0.5708 - accuracy: 0.7082 - val_loss: 0.7994 - val_accuracy: 0.5439
# Epoch 42/50
# 288/288 [==============================] - 3s 10ms/step - loss: 0.5669 - accuracy: 0.7079 - val_loss: 0.6845 - val_accuracy: 0.6152
# Epoch 43/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5674 - accuracy: 0.7124 - val_loss: 0.9430 - val_accuracy: 0.4168
# Epoch 44/50
# 288/288 [==============================] - 2s 8ms/step - loss: 0.5666 - accuracy: 0.7135 - val_loss: 0.7283 - val_accuracy: 0.5917
# Epoch 45/50
# 288/288 [==============================] - 3s 9ms/step - loss: 0.5640 - accuracy: 0.7090 - val_loss: 0.8855 - val_accuracy: 0.4563
# Epoch 46/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.5650 - accuracy: 0.7106 - val_loss: 0.6614 - val_accuracy: 0.6108
# Epoch 47/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.5643 - accuracy: 0.7131 - val_loss: 0.6050 - val_accuracy: 0.6697
# Epoch 48/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5649 - accuracy: 0.7148 - val_loss: 0.8410 - val_accuracy: 0.4737
# Epoch 49/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.5604 - accuracy: 0.7151 - val_loss: 0.7106 - val_accuracy: 0.5902
# Epoch 50/50
# 288/288 [==============================] - 1s 5ms/step - loss: 0.5591 - accuracy: 0.7166 - val_loss: 0.7220 - val_accuracy: 0.5880

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_9.history['loss'])
plt.plot(history_9.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# - there is a lot of noise in the model.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat9 = model9.predict(X_test)

# keep probabilities for the positive outcome only
yhat9 = yhat9[:, 0]

# calculate roc curves
fpr, tpr, thresholds9 = roc_curve(y_test, yhat9)

# calculate the g-mean for each threshold
gmeans9 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans9)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds9[ix], gmeans9[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.419679, G-Mean=0.687

# %%
y_pred_e9=model9.predict(X_test)
y_pred_e9 = (y_pred_e9 > thresholds9[ix])
y_pred_e9
# Out:
# 120/120 [==============================] - 0s 2ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm9=confusion_matrix(y_test, y_pred_e9)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm9, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
# Accuracy as per the classification report 

from sklearn import metrics
cr6=metrics.classification_report(y_test,y_pred_e9)
print(cr6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79      2877
#            1       0.44      0.64      0.53       955
#
#     accuracy                           0.71      3832
#    macro avg       0.65      0.69      0.66      3832
# weighted avg       0.76      0.71      0.73      3832

# %% [markdown]
# - After applying the SMOTE technique to the data, the F1 score increased, and the False Negative rate decreased, but if you see the loss curves of train and validation, the model seems to have overfit.

# %% [markdown]
# - Grid Search CV and see if we can increase the model's performance on the metrics.

# %%
backend.clear_session()
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
def create_model_v7(lr,batch_size):  
    np.random.seed(1337)
    model = Sequential()
    model.add(Dense(256,activation='relu',input_dim = X_train.shape[1]))
    model.add(Dropout(0.3))

    #model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.2))
    
    #model.add(Dense(32,activation='relu',kernel_initializer='he_uniform'))
    #model.add(Dropout(0.3))
    model.add(Dense(32,activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))

    #compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v7, verbose=1)

# %%
# define the grid search parameters

param_grid = {
    'batch_size':[32, 64, 128],
    "lr":[0.001,0.01,0.1],}

kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,  
                    verbose=1,
                    cv=kfold_splits,  
                    param_grid=param_grid,n_jobs=-1)
grid_result = grid.fit(X_train, y_train,validation_split=0.2,verbose=1)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 384/384 [==============================] - 2s 4ms/step - loss: 0.6596 - accuracy: 0.7210 - val_loss: 0.5673 - val_accuracy: 0.7515

# %%
# Summarize results

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# Out:
# Best: 0.750620 using {'batch_size': 32, 'lr': 0.001}

# %%
estimator_v7=create_model_v7(batch_size=grid_result.best_params_['batch_size'],lr=grid_result.best_params_['lr'])
estimator_v7.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               2560
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(grid_result.best_params_['lr'])
estimator_v7.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history_7=estimator_v7.fit(X_sm, y_sm, epochs=50, batch_size = grid_result.best_params_['batch_size'], verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 576/576 [==============================] - 3s 4ms/step - loss: 0.7492 - accuracy: 0.5929 - val_loss: 0.9806 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6688 - accuracy: 0.6199 - val_loss: 0.9184 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 576/576 [==============================] - 3s 5ms/step - loss: 0.6615 - accuracy: 0.6227 - val_loss: 0.9198 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 576/576 [==============================] - 3s 6ms/step - loss: 0.6560 - accuracy: 0.6235 - val_loss: 0.8747 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6487 - accuracy: 0.6255 - val_loss: 0.9312 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6427 - accuracy: 0.6322 - val_loss: 0.9302 - val_accuracy: 0.1367
# Epoch 7/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6369 - accuracy: 0.6424 - val_loss: 0.8498 - val_accuracy: 0.2260
# Epoch 8/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.6326 - accuracy: 0.6470 - val_loss: 0.8047 - val_accuracy: 0.3438
# Epoch 9/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6308 - accuracy: 0.6497 - val_loss: 0.8507 - val_accuracy: 0.3055
# Epoch 10/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6248 - accuracy: 0.6577 - val_loss: 0.7893 - val_accuracy: 0.4457
# Epoch 11/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6229 - accuracy: 0.6597 - val_loss: 0.7717 - val_accuracy: 0.4915
# Epoch 12/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.6185 - accuracy: 0.6689 - val_loss: 0.6912 - val_accuracy: 0.5769
# Epoch 13/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6130 - accuracy: 0.6745 - val_loss: 0.7132 - val_accuracy: 0.5976
# Epoch 14/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6104 - accuracy: 0.6747 - val_loss: 0.7744 - val_accuracy: 0.4913
# Epoch 15/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.6074 - accuracy: 0.6786 - val_loss: 0.6911 - val_accuracy: 0.5730
# Epoch 16/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6037 - accuracy: 0.6826 - val_loss: 0.7770 - val_accuracy: 0.4902
# Epoch 17/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.6018 - accuracy: 0.6851 - val_loss: 0.8549 - val_accuracy: 0.3588
# Epoch 18/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5979 - accuracy: 0.6890 - val_loss: 0.9017 - val_accuracy: 0.3355
# Epoch 19/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5933 - accuracy: 0.6918 - val_loss: 0.7264 - val_accuracy: 0.6154
# Epoch 20/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5921 - accuracy: 0.6973 - val_loss: 0.7487 - val_accuracy: 0.5721
# Epoch 21/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5913 - accuracy: 0.6947 - val_loss: 0.6883 - val_accuracy: 0.6519
# Epoch 22/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5909 - accuracy: 0.6963 - val_loss: 0.8007 - val_accuracy: 0.4930
# Epoch 23/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.5880 - accuracy: 0.6971 - val_loss: 0.7480 - val_accuracy: 0.5617
# Epoch 24/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5877 - accuracy: 0.6979 - val_loss: 0.7626 - val_accuracy: 0.5698
# Epoch 25/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5885 - accuracy: 0.6959 - val_loss: 0.7383 - val_accuracy: 0.5971
# Epoch 26/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5884 - accuracy: 0.6988 - val_loss: 0.7855 - val_accuracy: 0.4850
# Epoch 27/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5858 - accuracy: 0.6990 - val_loss: 0.7306 - val_accuracy: 0.6023
# Epoch 28/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.5857 - accuracy: 0.6996 - val_loss: 0.7195 - val_accuracy: 0.6312
# Epoch 29/50
# 576/576 [==============================] - 2s 4ms/step - loss: 0.5843 - accuracy: 0.7020 - val_loss: 0.8189 - val_accuracy: 0.5093
# Epoch 30/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5831 - accuracy: 0.6987 - val_loss: 0.7475 - val_accuracy: 0.5960
# Epoch 31/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5838 - accuracy: 0.7023 - val_loss: 0.6578 - val_accuracy: 0.7053
# Epoch 32/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5828 - accuracy: 0.7006 - val_loss: 0.7947 - val_accuracy: 0.5648
# Epoch 33/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5823 - accuracy: 0.7048 - val_loss: 0.6416 - val_accuracy: 0.7095
# Epoch 34/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5825 - accuracy: 0.7036 - val_loss: 0.7154 - val_accuracy: 0.5987
# Epoch 35/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5808 - accuracy: 0.7003 - val_loss: 0.9158 - val_accuracy: 0.3796
# Epoch 36/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5816 - accuracy: 0.7032 - val_loss: 0.7108 - val_accuracy: 0.6380
# Epoch 37/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5817 - accuracy: 0.7013 - val_loss: 0.8540 - val_accuracy: 0.3927
# Epoch 38/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5811 - accuracy: 0.7048 - val_loss: 0.7111 - val_accuracy: 0.5967
# Epoch 39/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5808 - accuracy: 0.7013 - val_loss: 0.8723 - val_accuracy: 0.4246
# Epoch 40/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5785 - accuracy: 0.7060 - val_loss: 0.7836 - val_accuracy: 0.5363
# Epoch 41/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5802 - accuracy: 0.7057 - val_loss: 0.7735 - val_accuracy: 0.6060
# Epoch 42/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5787 - accuracy: 0.7045 - val_loss: 0.7158 - val_accuracy: 0.5958
# Epoch 43/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5797 - accuracy: 0.7053 - val_loss: 0.8268 - val_accuracy: 0.5424
# Epoch 44/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5788 - accuracy: 0.7020 - val_loss: 0.6741 - val_accuracy: 0.6930
# Epoch 45/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5780 - accuracy: 0.7043 - val_loss: 0.8468 - val_accuracy: 0.4841
# Epoch 46/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5779 - accuracy: 0.7071 - val_loss: 0.7584 - val_accuracy: 0.5574
# Epoch 47/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5780 - accuracy: 0.7073 - val_loss: 0.6843 - val_accuracy: 0.6478
# Epoch 48/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5783 - accuracy: 0.7056 - val_loss: 0.7941 - val_accuracy: 0.5491
# Epoch 49/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5761 - accuracy: 0.7118 - val_loss: 0.6382 - val_accuracy: 0.7299
# Epoch 50/50
# 576/576 [==============================] - 2s 3ms/step - loss: 0.5771 - accuracy: 0.7046 - val_loss: 0.6856 - val_accuracy: 0.6838

# %%
#Plotting Train Loss vs Validation Loss

plt.plot(history_7.history['loss'])
plt.plot(history_7.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# -  there is a lot of noise in the model.
# - Grid Search CV also does not seem to work that well on the SMOTE data.

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot

# predict probabilities
yhat10 = estimator_v7.predict(X_test)

# keep probabilities for the positive outcome only
yhat10 = yhat10[:, 0]

# calculate roc curves
fpr, tpr, thresholds10 = roc_curve(y_test, yhat10)

# calculate the g-mean for each threshold
gmeans10 = np.sqrt(tpr * (1-fpr))

# locate the index of the largest g-mean
ix = np.argmax(gmeans10)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds10[ix], gmeans10[ix]))

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')

# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()

# show the plot
pyplot.show()
# Out:
# 120/120 [==============================] - 0s 2ms/step
# Best Threshold=0.466113, G-Mean=0.681

# %%
y_pred_e10=estimator_v7.predict(X_test)
y_pred_e10 = (y_pred_e10 > thresholds10[ix])
y_pred_e10
# Out:
# 120/120 [==============================] - 0s 1ms/step
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Calculating the confusion matrix 

from sklearn.metrics import confusion_matrix
cm10=confusion_matrix(y_test, y_pred_e10)
labels = ['True Positive','False Negative','False Positive','True Negative']
categories = [ 'Not Changing Job','Changing Job']
make_confusion_matrix(cm10, 
                      group_names=labels,
                      categories=categories, 
                      cmap='Blues')

# %%
# Accuracy as per the classification report 

from sklearn import metrics
cr10=metrics.classification_report(y_test,y_pred_e10)
print(cr10)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77      2877
#            1       0.42      0.67      0.52       955
#
#     accuracy                           0.69      3832
#    macro avg       0.64      0.68      0.64      3832
# weighted avg       0.75      0.69      0.71      3832

# %% [markdown]
# - Oversampling using SMOTE did not help improve the F1 score.
# - The SMOTE oversampling technique does not work well, as both the models we tried building have overfitted on the training dataset.
# - The final model can be Model 4, which uses the Dropout regularization technique and works on the imbalanced dataset.
